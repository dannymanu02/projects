# %%
import pandas as pd
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/manojdannana/nltk_data...
# True

# %%
data = pd.read_csv('reddit_worldnews.csv')
data.head()
# Out:
#    Post_Index                                              Title  \
# 0           1  An anti-gay Hungarian politician has resigned ...
# 1           2                 Trump Impeached for Abuse of Power
# 2           3  Vladimir Putin's black belt revoked by interna...
# 3           4  Two weeks before his inauguration, Donald J. T...
# 4           5  Queen Elizabeth II has died, Buckingham Palace...
#
#    Num_Comments  Upvotes  Downvotes  Upvote_Ratio          Date_Posted  Flair  \
# 0           849   204547          0          0.93  2020-12-01 18:15:32    NaN
# 1           879   202909          0          0.88  2019-12-19 01:23:35  Trump
# 2           798   200149          0          0.89  2022-02-28 20:45:18    NaN
# 3           914   189352          0          0.84  2018-07-19 02:06:35    NaN
# 4           905   189025          0          0.79  2022-09-08 17:32:06    NaN
#
#   Post_Category  Top_Comment_Score
# 0           Top             7555.0
# 1           Top             5150.0
# 2           Top             2907.0
# 3           Top              249.0
# 4           Top                1.0

# %%
headlines = data['Title']

sia = SentimentIntensityAnalyzer()

def get_sentiment_label(sentiment_score):
    if sentiment_score['compound'] > 0:
        return 'positive'
    elif sentiment_score['compound'] < 0:
        return 'negative'
    else:
        return 'neutral'

sentiment_labels = []
for headline in headlines:
    sentiment_score = sia.polarity_scores(headline)
    sentiment_label = get_sentiment_label(sentiment_score)
    sentiment_labels.append(sentiment_label)

data['Sentiment_Label'] = sentiment_labels

# %%
data.head()
# Out:
#    Post_Index                                              Title  \
# 0           1  An anti-gay Hungarian politician has resigned ...
# 1           2                 Trump Impeached for Abuse of Power
# 2           3  Vladimir Putin's black belt revoked by interna...
# 3           4  Two weeks before his inauguration, Donald J. T...
# 4           5  Queen Elizabeth II has died, Buckingham Palace...
#
#    Num_Comments  Upvotes  Downvotes  Upvote_Ratio          Date_Posted  Flair  \
# 0           849   204547          0          0.93  2020-12-01 18:15:32    NaN
# 1           879   202909          0          0.88  2019-12-19 01:23:35  Trump
# 2           798   200149          0          0.89  2022-02-28 20:45:18    NaN
# 3           914   189352          0          0.84  2018-07-19 02:06:35    NaN
# 4           905   189025          0          0.79  2022-09-08 17:32:06    NaN
#
#   Post_Category  Top_Comment_Score Sentiment_Label
# 0           Top             7555.0        negative
# 1           Top             5150.0        negative
# 2           Top             2907.0         neutral
# 3           Top              249.0        positive
# 4           Top                1.0        negative

# %%
data["Sentiment_Label"].value_counts()
# Out:
# Sentiment_Label
# negative    1205
# neutral      649
# positive     557
# Name: count, dtype: int64

# %%
data.to_csv("reddit_worldnews_sentiments.csv")
