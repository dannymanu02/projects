# %% [markdown]
# # Intro to Natural Language Processing (NLP)
#
# The Natural Language Processing (NLP) field is incredibly vast, and it has applications in virtually every aspect of data science. In this notebook, we will walk through a **very brief** survey of NLP, and provide some instruction on a couple handy tools along the way.
#
# NLP tools span a wide range of implementations, and it is not uncommon for NLP packages to have conflicts with other Python libraries. So, to keep everything compatible in one place, it is recommended that you create a new pip environment for NLP projects. To set up an NLP pip environment for this lab, follow the steps in the "Pip Environment" section of the [Python Environment Setup page in Canvas](https://iu.instructure.com/courses/2181786/pages/week-1-%7C-python-environment-setup?module_item_id=30340853), and **use the *environment.yml* file provided in this folder.** This should install the packages you'll need for this lab.
#
# Next, **[download a spaCy NLP model](https://spacy.io/models)** based on your preferences (in the NLP environment) so you can use the spaCy library installed in the environment.
#
# *Optionally, if you prefer to use a different environment, install the following packages separately using pip: [Scikit-Learn](https://scikit-learn.org/stable/install.html#installing-the-latest-release), [spaCy](https://spacy.io/usage), [ScatterText](https://github.com/JasonKessler/scattertext#installation), [CorEx](https://ryanjgallagher.github.io/code/corex/example), and [vaderSentiment](https://github.com/cjhutto/vaderSentiment#installation).*

# %% [markdown]
# ## Preprocessing
#
# To illustrate preprocessing text data, we'll use the [spaCy](https://spacy.io/) package.
#
# *spaCy is capable of **much** more than what we will use it for in this lab. More advanced implementations of spaCy may require knowledge outside the scope of this course.*

# %%
! python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 46.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /Users/manojdannana/anaconda3/lib/python3.11/site-packages (from en-core-web-sm==3.7.1) (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/manojdannana/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/manojdannana/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/manojdannana/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/manojdannana/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/manojdannana/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /Users/manojdannana/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/manojdannana/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/manojdannana/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/manojdannana/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /Users/manojdannana/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /Users/manojdannana/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/manojdannana/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/manojdannana/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/manojdannana/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/manojdannana/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.10.12)
# Requirement already satisfied: jinja2 in /Users/manojdannana/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.2)
# Requirement already satisfied: setuptools in /Users/manojdannana/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (68.2.2)
# Requirement already satisfied: packaging>=20.0 in /Users/manojdannana/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/manojdannana/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /Users/manojdannana/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.3)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/manojdannana/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/manojdannana/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/manojdannana/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/manojdannana/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/manojdannana/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2023.11.17)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/manojdannana/anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/manojdannana/anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/manojdannana/anaconda3/lib/python3.11/site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /Users/manojdannana/anaconda3/lib/python3.11/site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/manojdannana/anaconda3/lib/python3.11/site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.3)
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.7.1
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import pandas as pd
import spacy
from spacy import displacy
print(spacy.__version__)
# Out:
# 3.7.4

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')
# %config InlineBackend.figure_formats = ['svg']

# %% [markdown]
# ### Tokenizing
#
# The very first part of dealing with text data is to collect each **term** or unitary element of text (e.g., words, punctuation, etc.) in the form of "tokens".

# %%
# depends on your choice of spaCy model
nlp = spacy.load('en_core_web_sm')

# %%
intro = '''The Natural Language Processing (NLP) field is incredibly vast,
and it has applications in virtually every aspect of data science.
In this notebook, we will walk through a **very brief** survey of NLP,
and provide some instruction on a couple handy tools along the way.
'''
doc = nlp(intro)

# %%
print([t.text for t in doc])
# Out:
# ['The', 'Natural', 'Language', 'Processing', '(', 'NLP', ')', 'field', 'is', 'incredibly', 'vast', ',', '\n', 'and', 'it', 'has', 'applications', 'in', 'virtually', 'every', 'aspect', 'of', 'data', 'science', '.', '\n', 'In', 'this', 'notebook', ',', 'we', 'will', 'walk', 'through', 'a', '*', '*', 'very', 'brief', '*', '*', 'survey', 'of', 'NLP', ',', '\n', 'and', 'provide', 'some', 'instruction', 'on', 'a', 'couple', 'handy', 'tools', 'along', 'the', 'way', '.', '\n']

# %%
for i, sentence in enumerate(doc.sents):
    print(f"sentence {i+1}\n\n", sentence)
# Out:
# sentence 1
#
#  The Natural Language Processing (NLP) field is incredibly vast,
# and it has applications in virtually every aspect of data science.
#
# sentence 2
#
#  In this notebook, we will walk through a **very brief** survey of NLP,
# and provide some instruction on a couple handy tools along the way.

# %%
df_intro = []

for token in doc:
    df_intro.append([
        token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
        token.shape_, token.is_alpha, token.is_stop
    ])

# %%
df_intro = pd.DataFrame(columns=["text", "lemma_", "pos_", "tag_", "dep_", "shape_", "is_alpha", "is_stop"],
                        data=df_intro)

# %%
df_intro.sample(5)
# Out:
#             text       lemma_  pos_ tag_    dep_ shape_  is_alpha  is_stop
# 27          this         this   DET   DT     det   xxxx      True     True
# 0            The          the   DET   DT     det    Xxx      True     True
# 16  applications  application  NOUN  NNS    dobj   xxxx      True    False
# 37          very         very   ADV   RB  advmod   xxxx      True     True
# 53         handy        handy   ADJ   JJ    amod   xxxx      True    False

# %% [markdown]
# What is a **stop word**?

# %%
df_intro[df_intro['is_stop']].sample(10)
# Out:
#        text   lemma_   pos_ tag_    dep_ shape_  is_alpha  is_stop
# 26       In       in    ADP   IN    prep     Xx      True     True
# 17       in       in    ADP   IN    prep     xx      True     True
# 56      the      the    DET   DT     det    xxx      True     True
# 50       on       on    ADP   IN    prep     xx      True     True
# 13      and      and  CCONJ   CC      cc    xxx      True     True
# 31     will     will    AUX   MD     aux   xxxx      True     True
# 33  through  through    ADP   IN    prep   xxxx      True     True
# 37     very     very    ADV   RB  advmod   xxxx      True     True
# 34        a        a    DET   DT     det      x      True     True
# 42       of       of    ADP   IN    prep     xx      True     True

# %% [markdown]
# spaCy defines **lemmas** to be *"the base forms of words. For example, the lemma of `was` is `be`, and the lemma of `rats` is `rat`."*

# %%
t = nlp('running')[0]
t.lemma_
# Out:
# 'run'

# %% [markdown]
# **Sentence Dependencies**

# %% [markdown]
# We can visualize some of these attributes (like the sentence dependencies) using [displacy](https://spacy.io/usage/visualizers).

# %%
doc = nlp('We can visualize these using displacy.')

# %%
displacy.render(doc, style='dep', options={'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="332fed7fd6e84757b479d20f85596df1-0" class="displacy" width="770" height="317.0" direction="ltr" style="max-width: none; height: 317.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">We</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">can</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">visualize</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">these</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">using</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">displacy.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-332fed7fd6e84757b479d20f85596df1-0-0" stroke-width="2px" d="M70,182.0 C70,62.0 285.0,62.0 285.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-332fed7fd6e84757b479d20f85596df1-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,184.0 L62,172.0 78,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-332fed7fd6e84757b479d20f85596df1-0-1" stroke-width="2px" d="M190,182.0 C190,122.0 280.0,122.0 280.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-332fed7fd6e84757b479d20f85596df1-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M190,184.0 L182,172.0 198,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-332fed7fd6e84757b479d20f85596df1-0-2" stroke-width="2px" d="M430,182.0 C430,62.0 645.0,62.0 645.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-332fed7fd6e84757b479d20f85596df1-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M430,184.0 L422,172.0 438,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-332fed7fd6e84757b479d20f85596df1-0-3" stroke-width="2px" d="M550,182.0 C550,122.0 640.0,122.0 640.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-332fed7fd6e84757b479d20f85596df1-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M550,184.0 L542,172.0 558,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-332fed7fd6e84757b479d20f85596df1-0-4" stroke-width="2px" d="M310,182.0 C310,2.0 650.0,2.0 650.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-332fed7fd6e84757b479d20f85596df1-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M650.0,184.0 L658.0,172.0 642.0,172.0" fill="currentColor"/>
# </g>
# </svg></span>

# %% [markdown]
# Note: this isn't always going to be *exactly* accurate, but it's very good and still useful.

# %% [markdown]
# ### Named Entity Recognition
#
# Some words are **Named Entities**: locations like "Alaska", dates like "January 1st", companies like "Google", etc. spaCy can tag these using [Named Entity Recognition](https://spacy.io/usage/linguistic-features#named-entities).

# %%
doc = nlp('... locations like "Alaska", dates like "January 1st", companies like "Google", etc.')

# %%
displacy.render(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">... locations like &quot;
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alaska
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# &quot;, dates like &quot;
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     January 1st
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# &quot;, companies like &quot;
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# &quot;, etc.</div></span>

# %% [markdown]
# ### Multiple Documents
#
# *NLP Terms: A **document** is a collection of **tokens**, and a **corpus** is a collection of documents.*
#
# When spaCy processes text, it runs it through a [pipeline](https://spacy.io/usage/processing-pipelines) of different models to store token attributes for each token. This is how we get the functionality above. Though, when we are tokenizing multiple documents, we might not need all of these [built-in components](https://spacy.io/usage/processing-pipelines#built-in). For example, we might just need enough to filter our text based on the analysis done.
#
# For example, suppose we've determined that we want to the remove the following tokens from a dataset of [coffee reviews](https://www.kaggle.com/datasets/schmoyote/coffee-reviews-dataset/) (descriptions):
#
# - stop words (except the lemma "not", to maintain the idea of object negation)
# - punctuation
# - numbers
#
# In this case, we don't need NER, Dependency Labels, or Document Labels. Removing these processes from the spaCy pipeline will save us some time.

# %%
df_coffee = pd.read_csv('./data/coffee_analysis.csv')

# %%
df_coffee.drop_duplicates(subset='desc_1', inplace=True)

# %%
df_coffee.shape
# Out:
# (2092, 12)

# %%
print(df_coffee['desc_1'].sample().iloc[0])
# Out:
# Floral-toned, richly sweet-savory. Black cherry, dark chocolate, marjoram, sandalwood, agave syrup in aroma and cup. Sweetly tart structure with brisk acidity; syrupy-smooth mouthfeel. The finish leads with notes of black cherry, rounding to cocoa tones in the long.

# %%
# nlp.pipe returns a generator
docs = nlp.pipe(df_coffee['desc_1'], disable=['ner', 'parser', 'textcat'])

# save the spaCy objects into the DataFrame
df_coffee['spacy_doc'] = list(docs)

# %%
def tokenizer(doc, join_tokens=False):
    '''
    Tokenize a single spaCy `doc`.

    join_tokens : bool
        Whether we want to return a list of strings or
        a list of lists. If True, join with space (" ").
    '''

    # collect lemmas that meet the following criteria:
    tokens = [w.lemma_.lower() for w in doc if
              (not w.is_stop
               and not w.is_punct
               and not w.like_num) \
              or (w.lemma_ == 'not')]

    if join_tokens:
        return ' '.join(tokens)
    else:
        return tokens

# %%
df_coffee['docs_clean'] = df_coffee['spacy_doc'].apply(tokenizer)

# %%
df_coffee[['desc_1', 'spacy_doc', 'docs_clean']].head()
# Out:
#                                               desc_1  \
# 0  Evaluated as espresso. Sweet-toned, deeply ric...
# 1  Evaluated as espresso. Sweetly tart, floral-to...
# 2  Crisply sweet, cocoa-toned. Lemon blossom, roa...
# 3  Delicate, sweetly spice-toned. Pink peppercorn...
# 4  Deeply sweet, subtly pungent. Honey, pear, tan...
#
#                                            spacy_doc  \
# 0  (Evaluated, as, espresso, ., Sweet, -, toned, ...
# 1  (Evaluated, as, espresso, ., Sweetly, tart, ,,...
# 2  (Crisply, sweet, ,, cocoa, -, toned, ., Lemon,...
# 3  (Delicate, ,, sweetly, spice, -, toned, ., Pin...
# 4  (Deeply, sweet, ,, subtly, pungent, ., Honey, ...
#
#                                           docs_clean
# 0  [evaluate, espresso, sweet, tone, deeply, rich...
# 1  [evaluate, espresso, sweetly, tart, floral, to...
# 2  [crisply, sweet, cocoa, tone, lemon, blossom, ...
# 3  [delicate, sweetly, spice, tone, pink, pepperc...
# 4  [deeply, sweet, subtly, pungent, honey, pear, ...

# %%
print(df_coffee['desc_1'].iloc[5])
# Out:
# Delicate, richly and sweetly tart. Dried hibiscus, fine musk, almond, sandalwood, raspberry in aroma and cup. Fruit-toned, deeply sweet structure with gently-expressed acidity; buoyant, satiny-smooth mouthfeel. The crisp, flavor-saturated finish is characterized by sweet-tart fruit and floral tones (raspberry, hibiscus).

# %%
print(df_coffee['docs_clean'].iloc[5])
# Out:
# ['delicate', 'richly', 'sweetly', 'tart', 'dry', 'hibiscus', 'fine', 'musk', 'almond', 'sandalwood', 'raspberry', 'aroma', 'cup', 'fruit', 'tone', 'deeply', 'sweet', 'structure', 'gently', 'express', 'acidity', 'buoyant', 'satiny', 'smooth', 'mouthfeel', 'crisp', 'flavor', 'saturate', 'finish', 'characterize', 'sweet', 'tart', 'fruit', 'floral', 'tone', 'raspberry', 'hibiscus']

# %% [markdown]
# ## Vectorization
#
# Once we have our tokens selected and "cleaned", we need to convert the textual data into numerical data. **In other words, we need to convert each token (or document) into a *vector* representation.** There are many ways to represent textual information in the form of numerical data, but in this class we will cover Count Vectorization and Term-Frequency Inverse Document Frequency Vectorization; we'll call these **vectorizers**.

# %% [markdown]
# ### Brief Intro to Scikit-Learn
#
# **[Scikit-Learn](https://scikit-learn.org/stable/index.html) is the industry standard data science toolkit**, and it's modules are used in almost every aspect of data science. Here, we are going to use its [feature extraction module](https://scikit-learn.org/stable/modules/feature_extraction.html), which is built for extracting numerical features from data such as text or images. We will be using it for vectorization of text data, and in these cases, the scikit-learn process is:
#
# 1. Preprocess some data (e.g., from text to tokens)
# 2. Define a model (e.g., a vectorizer)
# 3. "Fit" that model to the data using `.fit`
# 4. Transform the data based on the model's parameters using `.transform`
#     - We can also combine these last two steps with `.fit_transform`

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %% [markdown]
# ### CountVectorizer
#
# CountVectorizer converts each document into a "Bag of Words". In other words, the document is encoded based on the words it contains, **regardless of the order**. And, each term can be represented based on the documents it is contained in.

# %%
corpus_raw = ['This coffee is really really tasty.',
              'Tea smells and tastes better than coffee.',
              "Best smelling coffee I have ever smelled!"]

# %%
cv = CountVectorizer(ngram_range=(1, 1),  # capture "pairs", or "n-tuples" of adjacent words
                     max_df=1.0,          # exclude terms in ≥ `max_df` (or %) of docs
                     min_df=1,            # exclude terms in ≤ `min_df` (or %) of docs
                     max_features=None,   # maximum number of terms/ngrams to include
                     binary=False)        # only log 1s and 0s for term presence

X = cv.fit_transform(corpus_raw)

df = pd.DataFrame(X.toarray(),
                  index=corpus_raw,
                  columns=cv.get_feature_names_out())

# %%
plt.figure(figsize=(8, 1))
g = sns.heatmap(df, cmap='Blues', annot=True, cbar=False, linewidths=1)

# %% [markdown]
# This is called a **document-term matrix**.
#
# - We could use `max_df` to remove the term "coffee" since it occurs in every document. This is one example of extracting *informative* features from text; i.e., the term "coffee" doesn't provide new information for each document.
# - Also, we can already see that some of these words give us more information than others. For example, "smelling" and "smells" mean roughly the same thing, and "had"/"have" aren't really necessary for understanding reviews.
#
# This is why we use the filtering in spaCy.

# %%
docs = nlp.pipe(corpus_raw)
corpus_clean = [tokenizer(d, True) for d in docs]
corpus_clean
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 2
#       1 docs = nlp.pipe(corpus_raw)
# ----> 2 corpus_clean = [tokenizer(d, True) for d in docs]
#       3 corpus_clean
#
# Cell In[25], line 2, in <listcomp>(.0)
#       1 docs = nlp.pipe(corpus_raw)
# ----> 2 corpus_clean = [tokenizer(d, True) for d in docs]
#       3 corpus_clean
#
# NameError: name 'tokenizer' is not defined

# %%
cv = CountVectorizer(ngram_range=(1, 1),
                     max_df=0.9,
                     min_df=1,
                     max_features=None,
                     binary=False)

X = cv.fit_transform(corpus_clean)

df = pd.DataFrame(X.toarray(),
                  index=corpus_raw,
                  columns=cv.get_feature_names_out())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 7
#       1 cv = CountVectorizer(ngram_range=(1, 1),
#       2                      max_df=0.9,
#       3                      min_df=1,
#       4                      max_features=None,
#       5                      binary=False)
# ----> 7 X = cv.fit_transform(corpus_clean)
#       9 df = pd.DataFrame(X.toarray(),
#      10                   index=corpus_raw,
#      11                   columns=cv.get_feature_names_out())
#
# NameError: name 'corpus_clean' is not defined

# %%
plt.figure(figsize=(6, 1))
g = sns.heatmap(df, cmap='Blues', annot=True, cbar=False, linewidths=1)

# %%
cv = CountVectorizer(ngram_range=(2, 2),  # use (1, 2) for unigrams *and* bigrams
                     max_df=0.9,
                     min_df=1,
                     max_features=None,
                     binary=False)

X = cv.fit_transform(corpus_clean)

df = pd.DataFrame(X.toarray(),
                  index=corpus_clean,
                  columns=cv.get_feature_names_out())

# %%
plt.figure(figsize=(10, 1))
g = sns.heatmap(df, cmap='Blues', annot=True, cbar=False, linewidths=1)

# %% [markdown]
# Now these vectors are a bit more meaningful. Notice, in a way, bigrams are a contrived way to capture context in textual data.

# %% [markdown]
# ### TFIDF Vectorizer
#
# Downsides of Count Vectorizer:
#
# - Counts can be too simplistic
# - High counts can dominate, especially for high frequency words or long documents
# - Each word is treated equally, when some terms might be more "important" than others
#
# We define TFIDF as:
#
# $$
# \text{TF-IDF} = \text{term frequency} * \text{inverse document frequency}
# $$
#
# where:
#
# $$
# \begin{align*}
# \text{term frequency} &= \frac{\text{term count in document}}{\text{total terms in document}} \\[8pt]
# \text{inverse document frequency} &= \log\bigg(\frac{\text{total number of documents} + 1}{\text{number of documents with term} + 1}\bigg)
# \end{align*}
# $$

# %% [markdown]
# This measure is calculated for every term-document combination:
#
# - The **term frequency** measures the "density" of a word in a document
# - The **inverse document frequency** (without the $\log$) measures the size of the corpus *in terms of* the number of documents containing the term. E.g., if IDF=5 then the corpus is 5 times the size of the "sub-corpus" of documents containing the term. The $\log$ dampens the effect of the inverse document frequency as the denominator gets very small or the numerator gets very large.
#
# So, we can think of TF as the "main" measure, and IDF as the "scaling" factor:
#
# - Very common words across all documents will get a lower score.
# - Rare words considering all documents get a higher score.

# %%
cv = TfidfVectorizer(max_df=1.0,
                     min_df=1,
                     max_features=None)

X = cv.fit_transform(corpus_clean)

df = pd.DataFrame(X.toarray(),
                  index=corpus_clean,
                  columns=cv.get_feature_names_out())

# %%
sns.heatmap(df, square=True, cmap='Blues', annot=True, cbar=False);

# %% [markdown]
# ## Topic Modeling
#
# ### Matrix Decomposition
#
# The document term matrix $X$ is a matrix just like any other in Linear Algebra. Just so, it defines a row space (the documents represented as linear combinations of terms), and column space (terms represented as a linear combination of documents). With this, there are a few matrix decomposition methods we can use to extract further information about these documents and terms.

# %%
from sklearn.decomposition import TruncatedSVD, NMF, PCA

# %% [markdown]
# ### Singular Value Decomposition
#
# Singular Value Decomposition is a guaranteed decomposition for any rectangular matrix. It creates the following equality:
#
# $$
# X = U\Sigma V^\top
# $$
#
# **Breifly**:
# - Each row of $U$ represents the corresponding document in terms of "topics directions" along the columns.
# - The rows of $V$ (columns of $V^\top$) represent similarly represented version of the terms.
# - The $\Sigma$ matrix contains the "variance explained" by each of these topics, sorted in descending order.
#
# As far as naming goes:
#
# - The analysis of these resulting matrices is called **Principal Components Analysis (PCA)**.
# - When used with text data, this analysis is called **Latent Semantic Analysis (LSA)**.

# %%
# we need a list/array of strings to vectorize
corpus = df_coffee['spacy_doc'].apply(tokenizer, args={'join_tokens':True})

# %%
corpus.shape
# Out:
# (2092,)

# %%
cv = TfidfVectorizer(max_df=0.9,
                     min_df=0.1,
                     max_features=None)

X = cv.fit_transform(corpus)
# df = pd.DataFrame(X, index=corpus, columns=cv.get_feature_names_out())

# %%
X.shape
# Out:
# (2092, 65)

# %% [markdown]
# Note, we use `TruncatedSVD` here because it's a more efficient implementation of SVD. PCA centers the data before running the algorithm, which is more "appropriate" but takes more time. This does cause a few inconsistencies in the "sorted" $\Sigma$.

# %%
lsa = TruncatedSVD(n_components=5)  # results only change for larger (unseen) values

doc_topic = lsa.fit_transform(X)
lsa.explained_variance_ratio_
# Out:
# array([0.00488089, 0.08197356, 0.04777372, 0.0467806 , 0.03499091])

# %%
doc_topic = pd.DataFrame(doc_topic.round(3),
                         index=df_coffee['desc_1'])
# doc_topic.head()

# %%
topic = 1
n_docs = 5

print(f"Top Documents for topic {topic}:\n")

for doc in doc_topic[topic].abs().sort_values(ascending=False).iloc[:n_docs].index:
    print(doc, '\n')
# Out:
# Top Documents for topic 1:
#
# Sweetly floral and delicately cocoa-toned. Honeysuckle, cocoa nib, Concord grape, agave, lemon-thyme in aroma and cup. High-toned structure with juicy, confident acidity; buoyant, lively, viscous mouthfeel. Honeysuckle and cocoa nib characterize the sweet finish.
#
# Evaluated as espresso. Roast-rounded, chocolaty. Dark chocolate, gardenia, gently scorched cedar, molasses, prune in aroma and small cup. Viscous, creamy mouthfeel; chocolaty, slightly smoky finish. In three parts milk, floral and chocolate notes preside.
#
# Evaluated as espresso. Fruit-forward, chocolaty. Dark chocolate, black cherry, lily, molasses, cedar in aroma and small cup. Very syrupy mouthfeel; crisp, chocolaty finish. In three parts milk, dark chocolate notes take center stage, supported by notes of black cherry and lily.
#
# Evaluated as espresso. Bittersweet, richly pungent, chocolaty and floral. Dark chocolate, plum, cedar, magnolia in aroma and small cup. Plump, satiny mouthfeel; bittersweet and chocolaty in the finish. Chocolate and flowers dominate in three parts milk.
#
# Delicately sweet-tart, floral-toned. Narcissus, apricot, cocoa nib, lemon verbena, frankincense in aroma and cup. Sweet-tart structure with delicately juicy acidity; very full, syrupy mouthfeel. Cocoa nib and narcissus focus the long, lingering finish.

# %%
topic_term = pd.DataFrame(lsa.components_.round(3),
                          columns = cv.get_feature_names_out())

topic_term
# Out:
#    acidity  almond   bake  balanced  bright  brisk  butter  cedar  center  \
# 0    0.192   0.124  0.090     0.103   0.117  0.072   0.068  0.167   0.082
# 1    0.072  -0.025 -0.142     0.065   0.120 -0.019  -0.019 -0.107  -0.003
# 2    0.038   0.066  0.300    -0.046  -0.126  0.197   0.057  0.150  -0.008
# 3   -0.121   0.011 -0.110    -0.007   0.011 -0.085   0.033  0.066  -0.012
# 4   -0.082  -0.171 -0.118     0.018  -0.164 -0.027  -0.081 -0.115  -0.054
#
#    chocolate  ...  sweet  sweetly  syrup  syrupy   tart   tone  undertone  \
# 0      0.256  ...  0.280    0.146  0.079   0.144  0.195  0.249      0.077
# 1     -0.461  ...  0.034    0.029  0.041   0.038  0.113  0.032     -0.016
# 2     -0.071  ...  0.098   -0.053  0.056  -0.149 -0.103  0.107      0.057
# 3     -0.031  ... -0.173   -0.038 -0.046  -0.041  0.032  0.097      0.005
# 4     -0.063  ...  0.086   -0.157 -0.057   0.045 -0.382 -0.070      0.035
#
#    velvety  vibrant   zest
# 0    0.070    0.066  0.148
# 1   -0.046    0.070  0.040
# 2    0.127   -0.090  0.019
# 3   -0.014   -0.018  0.011
# 4    0.016   -0.049 -0.064
#
# [5 rows x 65 columns]

# %%
# the third "topic"
topic = 2
n_terms = 10

topic_term.T[topic].abs().sort_values(ascending=False).iloc[:n_terms]
# Out:
# bake          0.300
# sandalwood    0.268
# dark          0.258
# nut           0.237
# flavor        0.218
# savory        0.207
# juicy         0.207
# cut           0.198
# brisk         0.197
# hazelnut      0.189
# Name: 2, dtype: float64

# %% [markdown]
# ### Non-Negative Matrix Factorization
#
# [NMF](https://en.wikipedia.org/wiki/Non-negative_matrix_factorization) is very similar to SVD. Here, we have the following decomposition.
#
# $$
# X = WH
# $$
#
# In this case though, all values in $W$ and $H$ are positive, and we can *approximate* this decomposition because all values in $X$ are positive.

# %%
nmf = NMF(4)  # here, the number will change the results
doc_topic = nmf.fit_transform(X)

# %%
doc_topic = pd.DataFrame(doc_topic.round(3),
                         index=df_coffee['desc_1'])
# doc_topic.head()

# %%
topic = 1
n_docs = 5

print(f"Top Documents for topic {topic}:\n")

for doc in doc_topic[topic].abs().sort_values(ascending=False).iloc[:n_docs].index:
    print(doc, '\n')
# Out:
# Top Documents for topic 1:
#
# Evaluated as espresso. Fruit-forward, chocolaty. Dark chocolate, black cherry, lily, molasses, cedar in aroma and small cup. Very syrupy mouthfeel; crisp, chocolaty finish. In three parts milk, dark chocolate notes take center stage, supported by notes of black cherry and lily.
#
# Evaluated as espresso. Bittersweet, richly pungent, chocolaty and floral. Dark chocolate, plum, cedar, magnolia in aroma and small cup. Plump, satiny mouthfeel; bittersweet and chocolaty in the finish. Chocolate and flowers dominate in three parts milk.
#
# Evaluated as espresso. Deeply chocolaty, balanced, roast-rounded. Dark chocolate, nectarine, molasses, gently scorched cedar, rhododendron in aroma and small cup. Full, satiny mouthfeel; crisp, chocolaty finish. In three parts milk the dark chocolate notes are amplified, as are the florals
#
# Evaluated as espresso. Roast-rounded, chocolaty. Dark chocolate, gardenia, gently scorched cedar, molasses, prune in aroma and small cup. Viscous, creamy mouthfeel; chocolaty, slightly smoky finish. In three parts milk, floral and chocolate notes preside.
#
# Evaluated as espresso. Richly chocolaty, fruit-toned. Dark chocolate, raspberry jam, cedar, caramel, lemon verbena in aroma and small cup. Crisp, syrupy-smooth mouthfeel; chocolaty, sweetly herbaceous finish. In three parts milk, raspberry notes recede and caramel and chocolate come forward.

# %%
topic_term = pd.DataFrame(nmf.components_.round(3),
                          columns = cv.get_feature_names_out())

topic_term
# Out:
#    acidity  almond   bake  balanced  bright  brisk  butter  cedar  center  \
# 0    0.934   0.391  0.000     0.612   0.863  0.000   0.083  0.022   0.351
# 1    0.000   0.173  0.000     0.047   0.000  0.000   0.133  0.603   0.114
# 2    0.547   0.485  0.961     0.104   0.000  0.611   0.301  0.660   0.210
# 3    0.492   0.163  0.000     0.363   0.487  0.017   0.112  0.284   0.167
#
#    chocolate  ...  sweet  sweetly  syrup  syrupy   tart   tone  undertone  \
# 0      0.805  ...  1.422    0.898  0.234   1.221  0.997  0.602      0.091
# 1      1.579  ...  0.029    0.135  0.000   0.173  0.178  0.398      0.179
# 2      0.709  ...  0.897    0.238  0.294   0.032  0.199  0.702      0.276
# 3      0.000  ...  0.503    0.333  0.230   0.308  0.705  0.737      0.192
#
#    velvety  vibrant   zest
# 0    0.000    0.557  0.650
# 1    0.118    0.000  0.136
# 2    0.438    0.000  0.353
# 3    0.048    0.260  0.377
#
# [4 rows x 65 columns]

# %%
topic = 0
n_terms = 10

topic_term.T[topic].sort_values(ascending=False).iloc[:n_terms]
# Out:
# savory        2.346
# sweet         1.422
# long          1.284
# flavor        1.231
# syrupy        1.221
# sandalwood    1.121
# juicy         1.121
# structure     1.107
# resonant      1.048
# richly        1.023
# Name: 0, dtype: float64

# %%
topic = 1
n_terms = 10

topic_term.T[topic].sort_values(ascending=False).iloc[:n_terms]
# Out:
# chocolate    1.579
# dark         1.304
# milk         1.131
# espresso     1.126
# evaluate     1.099
# small        1.096
# chocolaty    1.014
# cedar        0.603
# fruit        0.520
# floral       0.493
# Name: 1, dtype: float64

# %% [markdown]
# As you can tell, this often produces more agreeable results than LSA.

# %% [markdown]
# ### Latent Dirichlet Allocation (LDA)
#
# [LDA](https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.LatentDirichletAllocation.html) is a "generative" model that builds topics with the assumption that documents are generated based on a probability distribution of topics, and that topics are just a probability distribution of terms.

# %%
from sklearn.decomposition import LatentDirichletAllocation

# %%
# these parameters usually require a good bit of tuning ...
lda = LatentDirichletAllocation(n_components=5,
                                max_iter=50)

X_topics = lda.fit_transform(X)

# %%
df_lda = pd.DataFrame(data = X_topics,
                      index = corpus)

# %%
topic = 0
n_docs = 3

for d in df_lda[topic].sort_values(ascending=False).iloc[:n_docs].index:
    print(d, '\n')
# Out:
# richly sweet fruit forward dried apricot cocoa nib star jasmine almond maple syrup aroma cup sweetly tart structure bright juicy acidity crisp syrupy mouthfeel long linger finish center dry apricot cocoa note support cedar like wood
#
# delicate berry tone richly sweet raspberry honey narcissus like flower cedar almond butter aroma cup sweetly tart structure juicy high tone acidity lively mouthfeel resonant flavor saturate finish consolidate note raspberry almond support sweet floral hint
#
# high tone richly fruit forward balanced strawberry guava jasmine cocoa nib sandalwood pink grapefruit zest aroma cup sweet tart structure crisp bright acidity vibrantly plush syrupy mouthfeel resonant finish center guava jasmine note undertone cocoa nib

# %%
topic = 1
n_docs = 3

for d in df_lda[topic].sort_values(ascending=False).iloc[:n_docs].index:
    print(d, '\n')
# Out:
# deeply sweet richly nut tone hazelnut butter magnolia like flower crisp pear cedar agave syrup aroma cup sweet structure gentle round acidity syrupy smooth mouthfeel finish consolidate deep nut rich aromatic wood
#
# fruit tone richly chocolaty dark chocolate dry blueberry freesia like flower honey cedar aroma cup sweet tart structure round gentle acidity syrupy mouthfeel finish consolidate blueberry chocolate note hint cedar
#
# crisply sweet balanced spice tone bake chocolate almond butter date clove magnolia aroma cup sweet structure gentle round acidity plush syrupy mouthfeel chocolaty nut tone finish support magnolia like flower

# %%
df_lda_terms = pd.DataFrame(data = lda.components_,
                            columns = cv.get_feature_names_out())

# %%
topic = 0
n_terms = 10

df_lda_terms.T[topic].sort_values(ascending=False).iloc[:n_terms]
# Out:
# cocoa        173.729253
# nib          148.041852
# tart          91.054841
# tone          83.626504
# sweet         79.706775
# bright        76.706024
# juicy         74.092692
# acidity       71.742695
# structure     62.287788
# floral        55.370962
# Name: 0, dtype: float64

# %%
topic = 1
n_terms = 10

df_lda_terms.T[topic].sort_values(ascending=False).iloc[:n_terms]
# Out:
# chocolate    103.755570
# bake          79.127883
# chocolaty     76.855851
# cedar         70.560623
# sweet         69.585832
# tone          57.994594
# gentle        56.010294
# hazelnut      54.467662
# acidity       52.168683
# structure     50.941488
# Name: 1, dtype: float64

# %% [markdown]
# ### Anchored Correlation Explanation (CorEx)
#
# [CorEx](https://github.com/gregversteeg/corex_topic) is a discriminative model, which starts from $X$ (documents/words) to determine $Y$ (topics). CorEx looks for groups of words that are in the same topic, a.k.a. have high Total Correlation (TC), or convey the same information.
#
# - If words are **tightly related** (always appear together in the same topic/document), TC will be high. This is a good topic.
# - If the words are all **independent** (never appear together in the same document or topic), TC = 0. This is a bad topic.
# - CorEx creates a partition across terms. I.e., **terms can only occur in a single topic**.
#
# CorEx roughly follows this algorithm:
# 1. Look for a group of words that are both as broad (in many documents) and overlapping as possible (both together will lead to high TC), and call this a topic.
# 2. Repeat the process for another set of words (not overlapping with your previous group) with as high a TC as possible, and call this the next topic.
#
# As we create more topics, each subsequent topic will have lower TC.

# %%
from corextopic import corextopic as ct

# %%
# CorEx requires count data
cv = CountVectorizer(max_df=0.9,
                     min_df=0.1,
                     max_features=None)

X = cv.fit_transform(corpus)

# %%
topic_model = ct.Corex(n_hidden=5,                        # number of topics
                       words=cv.get_feature_names_out(),  # list of terms in corpus
                       seed=1)

doc_topic = topic_model.fit_transform(X, words=cv.get_feature_names_out(), docs=corpus)

# %%
# Print all topics from the CorEx topic model
topics = topic_model.get_topics()

for n, topic in enumerate(topics):
    topic_words,_,_ = zip(*topic)
    print(f"{n}: " + ','.join(topic_words))
# Out:
# 0: espresso,evaluate,small,milk,structure,acidity,consolidate,floral,syrup,crisp
# 1: chocolate,dark,nib,cocoa,chocolaty,bake,delicate,lemon,deep,zest
# 2: juicy,cut,gentle,bright,fresh,sandalwood,brisk,tart,high,nut
# 3: short,long,lead,undertone,rich,center,almond
# 4: sweet,sweetly,savory,deeply,fruit,smooth

# %% [markdown]
# Take a look at how you can use [anchor words](https://github.com/gregversteeg/corex_topic/tree/master#using-anchor-words) to guide the topic creation.

# %% [markdown]
# ## ScatterText
#
# Scattertext is great for
# - Visually inspecting text
# - Comparing/Contrasting corpora
# - And more...
#
# Check out Jason Kessler's GitHub project for more information: [here](https://github.com/JasonKessler/scattertext).

# %%
import scattertext as st

# %%
convention_df = st.SampleCorpora.ConventionData2012.get_data()

# %%
convention_df.head()
# Out:
#       party                                               text         speaker
# 0  democrat  Thank you. Thank you. Thank you. Thank you so ...    BARACK OBAMA
# 1  democrat  Thank you so much. Tonight, I am so thrilled a...  MICHELLE OBAMA
# 2  democrat  Thank you. It is a singular honor to be here t...  RICHARD DURBIN
# 3  democrat  Hey, Delaware. \nAnd my favorite Democrat, Jil...    JOSEPH BIDEN
# 4  democrat  Hello. \nThank you, Angie. I'm so proud of how...      JILL BIDEN

# %%
corpus = st.CorpusFromPandas(convention_df,
                             category_col='party',
                             text_col='text',
                             nlp=st.whitespace_nlp_with_sentences
                            ).build()

# %%
html = st.produce_scattertext_explorer(
        corpus,
        category='democrat',
        category_name='Democratic',
        not_category_name='Republican',
        minimum_term_frequency=10,
        pmi_threshold_coefficient=5,
        width_in_pixels=1000,
        metadata=convention_df['speaker'],
        )

# %%
with open('demo.html', 'wb') as f:
    f.write(html.encode('utf-8'))

# %% [markdown]
# ## Sentiment Analysis with VADER
#
# According to the documentation:
#
#     VADER (Valence Aware Dictionary and sEntiment Reasoner) is a lexicon and rule-based sentiment analysis tool that is specifically attuned to sentiments expressed in social media. [...]
#
#     Sentiment ratings from 10 independent human raters (all pre-screened, trained, and quality checked for optimal inter-rater reliability). Over 9,000 token features were rated on a scale from "[–4] Extremely Negative" to "[4] Extremely Positive", with allowance for "[0] Neutral (or Neither, N/A)".

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
sentences = ["VADER is smart, handsome, and funny.",  # positive sentence example
             "VADER is smart, handsome, and funny!",  # punctuation emphasis handled correctly (sentiment intensity adjusted)
             "VADER is very smart, handsome, and funny.", # booster words handled correctly (sentiment intensity adjusted)
             "VADER is VERY SMART, handsome, and FUNNY.",  # emphasis for ALLCAPS handled
             "VADER is VERY SMART, handsome, and FUNNY!!!", # combination of signals - VADER appropriately adjusts intensity
             "VADER is VERY SMART, uber handsome, and FRIGGIN FUNNY!!!", # booster words & punctuation make this close to ceiling for score
             "VADER is not smart, handsome, nor funny.",  # negation sentence example
             "The book was good.",  # positive sentence
             "At least it isn't a horrible book.",  # negated negative sentence with contraction
             "The book was only kind of good.", # qualified positive sentence is handled correctly (intensity adjusted)
             "The plot was good, but the characters are uncompelling and the dialog is not great.", # mixed negation sentence
             "Today SUX!",  # negative slang with capitalization emphasis
             "Today only kinda sux! But I'll get by, lol", # mixed sentiment example with slang and constrastive conjunction "but"
             "Make sure you :) or :D today!",  # emoticons handled
             # "Catch utf-8 emoji such as such as 💘 and 💋 and 😁",  # emojis handled, ignored for seaborn plot below
             "Not bad at all"  # Capitalized negation
             ]

# %%
df_sentiment = []

analyzer = SentimentIntensityAnalyzer()

for sentence in sentences:
    vs = analyzer.polarity_scores(sentence)
    df_sentiment.append(vs)

# %%
df_sentiment = pd.DataFrame(df_sentiment,
                            index = sentences)

# %%
sns.heatmap(df_sentiment, cmap='Blues', annot=True, cbar=False, linewidths=1);

# %% [markdown]
# # EXERCISES

# %% [markdown]
# ## Exercise 1
#
# Using a book from [Project Gutenberg](https://www.gutenberg.org/), get the text data directly from its URL using the `requests` package. Break the book into 50 or more sensible "chunks" like chapters or paragraphs, organizing them into a list.
#
# Load this data into a spaCy pipeline and analyze either Named Entities or Parts of Speech in each chunk.
#
# Provide your analysis: What types of entities or parts of speech are common, and what are uncommon? What insights can you draw from these patterns?
#
# *Note*: Do not download any file, make use of URL in your code.

# %% [markdown]
# ## The output is pretty big, my insights are given after the ouput ends.

# %%
# write your code here ...
import requests
import spacy

nlp = spacy.load("en_core_web_sm")

def chunk_text(text, chunk_size):
    chunks = []
    words = text.split()
    for i in range(0, len(words), chunk_size):
        chunks.append(" ".join(words[i:i+chunk_size]))
    return chunks
    
def analyze_chunks(chunks):
    analysis = []
    for chunk in chunks:
        doc = nlp(chunk)
        analysis.append([(token.text, token.pos_) for token in doc])
    return analysis

url = "https://www.gutenberg.org/cache/epub/73142/pg73142.txt"

response = requests.get(url)
text = response.text

chunks = chunk_text(text, 50)

analysis = analyze_chunks(chunks)

for i, chunk_analysis in enumerate(analysis):
    if i == 51:
        break
    print(f"Chunk {i+1} analysis:")
    for token, pos in chunk_analysis:
        print(f"{token}: {pos}")
    print("\n")
# Out:
# Chunk 1 analysis:
# ﻿The: NOUN
# Project: PROPN
# Gutenberg: PROPN
# eBook: PROPN
# of: ADP
# ": PUNCT
# We: PRON
# ": PUNCT
# This: DET
# ebook: NOUN
# is: AUX
# for: ADP
# the: DET
# use: NOUN
# of: ADP
# anyone: PRON
# anywhere: ADV
# in: ADP
# the: DET
# United: PROPN
# States: PROPN
# and: CCONJ
# most: ADJ
# other: ADJ
# parts: NOUN
# of: ADP
# the: DET
# world: NOUN
# at: ADP
# no: DET
# cost: NOUN
# and: CCONJ
# with: ADP
# almost: ADV
# no: PRON
# restrictions: NOUN
# whatsoever: ADV
# .: PUNCT
# You: PRON
# may: AUX
# copy: VERB
# it: PRON
# ,: PUNCT
# give: VERB
# it: PRON
# away: ADV
# or: CCONJ
# re: VERB
# -: VERB
# use: VERB
# it: PRON
# under: ADP
# the: DET
# terms: NOUN
# of: ADP
# the: PRON
#
#
# Chunk 2 analysis:
# Project: PROPN
# Gutenberg: PROPN
# License: PROPN
# included: VERB
# with: ADP
# this: DET
# ebook: NOUN
# or: CCONJ
# online: NOUN
# at: ADP
# www.gutenberg.org: NOUN
# .: PUNCT
# If: SCONJ
# you: PRON
# are: AUX
# not: PART
# located: VERB
# in: ADP
# the: DET
# United: PROPN
# States: PROPN
# ,: PUNCT
# you: PRON
# will: AUX
# have: VERB
# to: PART
# check: VERB
# the: DET
# laws: NOUN
# of: ADP
# the: DET
# country: NOUN
# where: SCONJ
# you: PRON
# are: AUX
# located: VERB
# before: ADP
# using: VERB
# this: DET
# eBook: PROPN
# .: PUNCT
# Title: NOUN
# :: PUNCT
# ": PUNCT
# We: PRON
# ": PUNCT
# The: DET
# famous: ADJ
# flier: NOUN
# 's: PART
# own: ADJ
# story: NOUN
# of: ADP
# his: PRON
# life: NOUN
# and: CCONJ
# his: PRON
#
#
# Chunk 3 analysis:
# trans: ADJ
# -: ADJ
# Atlantic: ADJ
# flight: NOUN
# ,: PUNCT
# together: ADV
# with: ADP
# his: PRON
# views: NOUN
# on: ADP
# the: DET
# future: NOUN
# of: ADP
# aviation: NOUN
# Author: NOUN
# :: PUNCT
# Charles: PROPN
# A.: PROPN
# Lindbergh: PROPN
# Contributor: PROPN
# :: PUNCT
# Fitzhugh: PROPN
# Green: PROPN
# Myron: PROPN
# T.: PROPN
# Herrick: PROPN
# Release: PROPN
# date: NOUN
# :: PUNCT
# March: PROPN
# 11: NUM
# ,: PUNCT
# 2024: NUM
# [: X
# eBook: VERB
# #: SYM
# 73142: NUM
# ]: PUNCT
# Language: NOUN
# :: PUNCT
# English: PROPN
# Original: ADJ
# publication: NOUN
# :: PUNCT
# United: PROPN
# States: PROPN
# :: PUNCT
# G.: PROPN
# P.: PROPN
# Putnam: PROPN
# 's: PART
# Sons: PROPN
# ,: PUNCT
# 1927: NUM
# Credits: NOUN
# :: PUNCT
# Tim: PROPN
# Lindell: PROPN
# ,: PUNCT
# David: PROPN
# E.: PROPN
# Brown: PROPN
# ,: PUNCT
# and: CCONJ
# the: DET
# Online: PROPN
# Distributed: VERB
# Proofreading: NOUN
#
#
# Chunk 4 analysis:
# Team: NOUN
# at: ADP
# https://www.pgdp.net: NOUN
# (: PUNCT
# This: DET
# file: NOUN
# was: AUX
# produced: VERB
# from: ADP
# images: NOUN
# generously: ADV
# made: VERB
# available: ADJ
# by: ADP
# The: DET
# Internet: PROPN
# Archive: PROPN
# /: SYM
# American: PROPN
# Libraries: PROPN
# .: PUNCT
# ): PUNCT
# *: PUNCT
# *: PUNCT
# *: PUNCT
# START: NOUN
# OF: ADP
# THE: DET
# PROJECT: PROPN
# GUTENBERG: PROPN
# EBOOK: VERB
# ": PUNCT
# WE: PROPN
# ": PUNCT
# *: PUNCT
# *: PUNCT
# *: PUNCT
# [: X
# Illustration: NOUN
# :: PUNCT
# ©: NOUN
# _: NOUN
# Wide: ADJ
# World: PROPN
# Photos: PROPN
# _: NOUN
# “: PUNCT
# WE: PROPN
# ”: PUNCT
# ]: PUNCT
# “: PUNCT
# WE: PROPN
# ”: PUNCT
# BY: ADP
# CHARLES: PROPN
# A.: NOUN
# LINDBERGH: VERB
# THE: DET
# FAMOUS: PROPN
# FLIER: PROPN
# ’S: PART
# OWN: PROPN
# STORY: PROPN
# OF: ADP
# HIS: PRON
# LIFE: NOUN
# AND: CCONJ
# HIS: PRON
# TRANSATLANTIC: PROPN
# FLIGHT: NOUN
# ,: PUNCT
# TOGETHER: ADV
# WITH: ADP
#
#
# Chunk 5 analysis:
# HIS: PRON
# VIEWS: NOUN
# ON: ADP
# THE: DET
# FUTURE: NOUN
# OF: ADP
# AVIATION: NOUN
# WITH: ADP
# A: DET
# FOREWORD: NOUN
# BY: NOUN
# MYRON: PROPN
# T.: PROPN
# HERRICK: NOUN
# U.: PROPN
# S.: PROPN
# AMBASSADOR: NOUN
# TO: ADP
# FRANCE: PROPN
# [: X
# Illustration: NOUN
# ]: PUNCT
# FULLY: ADV
# ILLUSTRATED: VERB
# G.: PROPN
# P.: PROPN
# PUTNAM: PROPN
# ’S: PART
# SONS: PROPN
# NEW: PROPN
# YORK: PROPN
# --: PUNCT
# LONDON: PROPN
# The: DET
# Knickerbocker: PROPN
# Press: PROPN
# 1927: NUM
# Copyright: PROPN
# ,: PUNCT
# 1927: NUM
# by: ADP
# Charles: PROPN
# A.: NOUN
# Lindbergh: PROPN
# This: PRON
# is: AUX
# a: DET
# copy: NOUN
# of: ADP
# the: DET
# First: PROPN
# Edition: PROPN
# of: ADP
# “: PUNCT
# WE: PROPN
# ”: PUNCT
# [: X
# Illustration: NOUN
# :: PUNCT
# G.P.: PROPN
#
#
# Chunk 6 analysis:
# Putnam: PROPN
# ’s: PART
# Sons: NOUN
# ]: PUNCT
# July: PROPN
# ,: PUNCT
# 1927: NUM
# [: X
# Illustration: NOUN
# :: PUNCT
# The: DET
# Knickerbocker: PROPN
# Press: PROPN
# New: PROPN
# York: PROPN
# ]: PUNCT
# Made: VERB
# in: ADP
# the: DET
# United: PROPN
# States: PROPN
# of: ADP
# America: PROPN
# DEDICATED: VERB
# TO: ADP
# MY: PRON
# MOTHER: NOUN
# AND: CCONJ
# TO: ADP
# THE: DET
# MEN: PROPN
# WHOSE: PRON
# CONFIDENCE: NOUN
# AND: CCONJ
# FORESIGHT: NOUN
# MADE: VERB
# POSSIBLE: ADJ
# THE: DET
# FLIGHT: NOUN
# OF: ADP
# THE: DET
# “: PUNCT
# SPIRIT: PROPN
# OF: ADP
# ST: PROPN
# .: PUNCT
# LOUIS: PROPN
# ”: PUNCT
# MR: PROPN
# .: PUNCT
# HARRY: PROPN
# H.: PROPN
# KNIGHT: PROPN
# MAJOR: PROPN
# WILLIAM: PROPN
# B.: PROPN
# ROBERTSON: PROPN
# MAJOR: PROPN
# ALBERT: PROPN
# BOND: PROPN
#
#
# Chunk 7 analysis:
# LAMBERT: PROPN
# MR: PROPN
# .: PUNCT
# J.: PROPN
# D.: PROPN
# WOOSTER: PROPN
# LAMBERT: PROPN
# MR: PROPN
# .: PUNCT
# HAROLD: PROPN
# M.: PROPN
# BIXBY: PROPN
# MR: PROPN
# .: PUNCT
# EARL: PROPN
# C.: PROPN
# THOMPSON: PROPN
# MR: PROPN
# .: PUNCT
# HARRY: PROPN
# F.: PROPN
# KNIGHT: PROPN
# MR: PROPN
# .: PUNCT
# E.: PROPN
# LANSING: PROPN
# RAY: PROPN
# FOREWORD: PROPN
# When: SCONJ
# Joan: PROPN
# of: ADP
# Arc: PROPN
# crowned: VERB
# her: PRON
# King: NOUN
# at: ADP
# Rheims: PROPN
# she: PRON
# became: VERB
# immortal: ADJ
# .: PUNCT
# When: SCONJ
# Lafayette: PROPN
# risked: VERB
# his: PRON
# all: PRON
# to: PART
# help: VERB
# the: DET
# struggling: VERB
# Americans: PROPN
# he: PRON
# wrote: VERB
# his: PRON
# memory: NOUN
# forever: ADV
#
#
# Chunk 8 analysis:
# across: ADP
# a: DET
# mighty: ADJ
# continent: NOUN
# .: PUNCT
# Shepherd: PROPN
# boy: NOUN
# David: PROPN
# in: ADP
# five: NUM
# minutes: NOUN
# achieved: VERB
# with: ADP
# his: PRON
# sling: NOUN
# a: DET
# place: NOUN
# in: ADP
# history: NOUN
# which: PRON
# has: AUX
# defied: VERB
# all: DET
# time: NOUN
# .: PUNCT
# These: DET
# three: NUM
# shining: VERB
# names: NOUN
# represent: VERB
# the: DET
# triumph: NOUN
# of: ADP
# the: DET
# idealism: NOUN
# of: ADP
# youth: NOUN
# ,: PUNCT
# and: CCONJ
# we: PRON
# would: AUX
# not: PART
# speak: VERB
# of: ADP
# them: PRON
# with: ADP
# such: ADJ
# reverence: NOUN
# today: NOUN
# had: AUX
# their: PRON
# motives: NOUN
# been: AUX
#
#
# Chunk 9 analysis:
# less: ADV
# pure: ADJ
# or: CCONJ
# had: VERB
# they: PRON
# ever: ADV
# for: ADP
# an: DET
# instant: ADJ
# thought: NOUN
# of: ADP
# themselves: PRON
# or: CCONJ
# their: PRON
# place: NOUN
# in: ADP
# history: NOUN
# .: PUNCT
# So: ADV
# it: PRON
# was: AUX
# with: ADP
# Lindbergh: PROPN
# ,: PUNCT
# and: CCONJ
# all: DET
# the: DET
# praise: NOUN
# awarded: VERB
# him: PRON
# ,: PUNCT
# judged: VERB
# by: ADP
# the: DET
# rigid: ADJ
# standards: NOUN
# of: ADP
# history: NOUN
# and: CCONJ
# precedent: NOUN
# ,: PUNCT
# he: PRON
# has: AUX
# merited: VERB
# .: PUNCT
# He: PRON
# was: AUX
# the: DET
# instrument: NOUN
# of: ADP
# a: DET
# great: ADJ
# ideal: NOUN
# and: CCONJ
# one: NUM
#
#
# Chunk 10 analysis:
# need: AUX
# not: PART
# be: AUX
# fanatically: ADV
# religious: ADJ
# to: PART
# see: VERB
# in: ADP
# his: PRON
# success: NOUN
# the: DET
# guiding: VERB
# hand: NOUN
# of: ADP
# providence: NOUN
# .: PUNCT
# For: SCONJ
# he: PRON
# was: AUX
# needed: VERB
# and: CCONJ
# he: PRON
# came: VERB
# at: ADP
# the: DET
# moment: NOUN
# which: PRON
# seemed: AUX
# exactly: ADV
# prëordained: VERB
# .: PUNCT
# He: PRON
# was: AUX
# needed: VERB
# by: ADP
# France: PROPN
# and: CCONJ
# needed: VERB
# by: ADP
# America: PROPN
# ,: PUNCT
# and: CCONJ
# had: VERB
# his: PRON
# arrival: NOUN
# been: AUX
# merely: ADV
# the: DET
# triumph: NOUN
# of: ADP
# a: DET
# great: ADJ
# adventure: NOUN
#
#
# Chunk 11 analysis:
# the: DET
# influence: NOUN
# of: ADP
# his: PRON
# act: NOUN
# would: AUX
# have: AUX
# gone: VERB
# no: ADV
# further: ADV
# than: SCONJ
# have: VERB
# other: ADJ
# great: ADJ
# sporting: NOUN
# and: CCONJ
# commercial: ADJ
# achievements: NOUN
# .: PUNCT
# There: PRON
# have: AUX
# been: AUX
# moments: NOUN
# here: ADV
# in: ADP
# France: PROPN
# when: SCONJ
# all: DET
# that: PRON
# my: PRON
# eye: NOUN
# could: AUX
# reach: VERB
# or: CCONJ
# my: PRON
# intelligence: NOUN
# fathom: PROPN
# appeared: VERB
# dark: ADJ
# and: CCONJ
# foreboding: NOUN
# and: CCONJ
# yet: ADV
# ,: PUNCT
# in: ADP
# spite: NOUN
# of: ADP
# all: PRON
# ,: PUNCT
# my: PRON
# soul: NOUN
# would: AUX
# be: AUX
#
#
# Chunk 12 analysis:
# warmed: VERB
# as: ADP
# by: ADP
# invisible: ADJ
# sunshine: NOUN
# .: PUNCT
# At: ADP
# such: ADJ
# times: NOUN
# when: SCONJ
# all: DET
# human: ADJ
# efforts: NOUN
# had: AUX
# apparently: ADV
# failed: VERB
# ,: PUNCT
# suddenly: ADV
# the: DET
# affairs: NOUN
# of: ADP
# nations: NOUN
# seemed: VERB
# to: PART
# be: AUX
# taken: VERB
# from: ADP
# out: ADP
# of: ADP
# the: DET
# hands: NOUN
# of: ADP
# men: NOUN
# and: CCONJ
# directed: VERB
# by: ADP
# an: DET
# unseen: ADJ
# power: NOUN
# on: ADP
# high: ADJ
# .: PUNCT
# Just: ADV
# before: ADP
# the: DET
# Battle: PROPN
# of: ADP
# the: DET
# Marne: PROPN
# I: PRON
# was: AUX
# standing: VERB
# on: ADP
#
#
# Chunk 13 analysis:
# the: DET
# Seine: PROPN
# embankment: NOUN
# .: PUNCT
# A: DET
# great: ADJ
# harvest: NOUN
# moon: NOUN
# was: AUX
# rising: VERB
# over: ADP
# the: DET
# city: NOUN
# near: ADP
# Notre: PROPN
# Dame: PROPN
# .: PUNCT
# It: PRON
# seemed: VERB
# to: PART
# rest: VERB
# on: ADP
# the: DET
# corner: NOUN
# of: ADP
# a: DET
# building: NOUN
# .: PUNCT
# The: DET
# French: ADJ
# flag: NOUN
# was: AUX
# blowing: VERB
# steadily: ADV
# across: ADP
# its: PRON
# face: NOUN
# .: PUNCT
# In: ADP
# fleeting: ADJ
# moments: NOUN
# while: SCONJ
# this: DET
# spectacle: NOUN
# lasted: VERB
# people: NOUN
# knelt: VERB
# on: ADP
# the: DET
# quay: NOUN
# in: ADP
# prayer: NOUN
# .: PUNCT
# I: PRON
# inquired: VERB
#
#
# Chunk 14 analysis:
# the: DET
# meaning: NOUN
# of: ADP
# these: DET
# prayers: NOUN
# .: PUNCT
# The: DET
# answer: NOUN
# was: AUX
# that: SCONJ
# there: PRON
# is: VERB
# a: DET
# prophecy: NOUN
# centuries: NOUN
# old: ADJ
# that: SCONJ
# the: DET
# fate: NOUN
# of: ADP
# France: PROPN
# will: AUX
# finally: ADV
# be: AUX
# settled: VERB
# upon: SCONJ
# the: DET
# fields: NOUN
# where: SCONJ
# Attila: PROPN
# ’s: PART
# horde: PROPN
# was: AUX
# halted: VERB
# and: CCONJ
# driven: VERB
# back: ADV
# and: CCONJ
# where: SCONJ
# many: ADJ
# battles: NOUN
# in: ADP
# defence: NOUN
# of: ADP
# France: PROPN
# have: AUX
# been: AUX
# won: VERB
# .: PUNCT
# And: CCONJ
# pointing: VERB
# up: ADP
# the: PRON
#
#
# Chunk 15 analysis:
# Seine: NOUN
# to: ADP
# the: DET
# French: ADJ
# flag: NOUN
# outlined: VERB
# across: ADP
# the: DET
# moon: NOUN
# people: NOUN
# cried: VERB
# ,: PUNCT
# “: PUNCT
# See: VERB
# ,: PUNCT
# see: VERB
# the: DET
# sign: NOUN
# in: ADP
# heaven: PROPN
# .: PUNCT
# It: PRON
# means: VERB
# the: DET
# victory: NOUN
# of: ADP
# French: ADJ
# arms: NOUN
# .: PUNCT
# The: DET
# prophecy: NOUN
# of: ADP
# old: ADJ
# is: AUX
# come: VERB
# true: ADJ
# and: CCONJ
# France: PROPN
# is: AUX
# once: ADV
# again: ADV
# to: PART
# be: AUX
# saved: VERB
# on: ADP
# those: DET
# chalky: ADJ
# fields: NOUN
# .: PUNCT
# ”: PUNCT
# Now: ADV
# when: SCONJ
# this: DET
# boy: NOUN
# of: ADP
# ours: NOUN
# came: VERB
#
#
# Chunk 16 analysis:
# unheralded: VERB
# out: ADP
# of: ADP
# the: DET
# air: NOUN
# ,: PUNCT
# and: CCONJ
# circling: VERB
# the: DET
# Eiffel: PROPN
# tower: NOUN
# settled: VERB
# to: PART
# rest: VERB
# as: ADV
# gently: ADV
# as: ADP
# a: DET
# bird: NOUN
# on: ADP
# the: DET
# field: NOUN
# at: ADP
# Le: PROPN
# Bourget: PROPN
# ,: PUNCT
# I: PRON
# was: AUX
# seized: VERB
# with: ADP
# the: DET
# same: ADJ
# premonition: NOUN
# as: ADP
# those: DET
# French: ADJ
# people: NOUN
# on: ADP
# the: DET
# quay: NOUN
# that: SCONJ
# August: PROPN
# night: NOUN
# .: PUNCT
# I: PRON
# felt: VERB
# without: ADP
# knowing: VERB
# why: SCONJ
# ,: PUNCT
# that: SCONJ
# his: PRON
# arrival: NOUN
# was: AUX
#
#
# Chunk 17 analysis:
# far: ADV
# more: ADJ
# than: SCONJ
# a: DET
# fine: ADJ
# deed: NOUN
# well: ADV
# accomplished: VERB
# ,: PUNCT
# and: CCONJ
# there: PRON
# glowed: VERB
# within: ADP
# me: PRON
# the: DET
# prescience: NOUN
# of: ADP
# splendor: NOUN
# yet: ADV
# to: PART
# come: VERB
# .: PUNCT
# Lo: PROPN
# !: PUNCT
# it: PRON
# did: AUX
# come: VERB
# and: CCONJ
# has: AUX
# gone: VERB
# on: ADP
# spreading: VERB
# its: PRON
# beneficence: NOUN
# upon: SCONJ
# two: NUM
# sister: NOUN
# nations: NOUN
# which: PRON
# a: DET
# now: ADV
# -: PUNCT
# conquered: VERB
# ocean: NOUN
# joins: VERB
# .: PUNCT
# For: SCONJ
# I: PRON
# feel: VERB
# with: ADP
# every: DET
# fibre: NOUN
# of: ADP
# my: PRON
# being: NOUN
# that: PRON
#
#
# Chunk 18 analysis:
# Lindbergh: PROPN
# ’s: PART
# landing: NOUN
# here: ADV
# marks: VERB
# one: NUM
# of: ADP
# the: DET
# supreme: ADJ
# moments: NOUN
# in: ADP
# the: DET
# history: NOUN
# of: ADP
# America: PROPN
# and: CCONJ
# France: PROPN
# ,: PUNCT
# and: CCONJ
# the: DET
# faith: NOUN
# we: PRON
# have: VERB
# in: ADP
# the: DET
# deciding: VERB
# power: NOUN
# of: ADP
# spiritual: ADJ
# things: NOUN
# is: AUX
# strengthened: VERB
# by: ADP
# every: DET
# circumstance: NOUN
# of: ADP
# his: PRON
# journey: NOUN
# ,: PUNCT
# by: ADP
# all: DET
# his: PRON
# acts: NOUN
# after: ADP
# landing: NOUN
# ,: PUNCT
# and: CCONJ
# by: ADP
# the: DET
# electrical: ADJ
# thrill: NOUN
# which: PRON
# ran: VERB
# like: ADP
#
#
# Chunk 19 analysis:
# some: DET
# religious: ADJ
# emotion: NOUN
# through: ADP
# a: DET
# whole: ADJ
# vast: ADJ
# population: NOUN
# .: PUNCT
# “: PUNCT
# The: DET
# Spirit: PROPN
# of: ADP
# St.: PROPN
# Louis: PROPN
# ”: PUNCT
# was: AUX
# to: ADP
# the: DET
# French: ADJ
# people: NOUN
# another: DET
# sign: NOUN
# come: VERB
# out: ADP
# of: ADP
# the: DET
# sky: NOUN
# --: PUNCT
# a: DET
# sign: NOUN
# which: PRON
# bore: VERB
# the: DET
# promise: NOUN
# that: PRON
# all: PRON
# would: AUX
# be: AUX
# well: ADV
# between: ADP
# them: PRON
# and: CCONJ
# us: PRON
# .: PUNCT
# What: PRON
# a: DET
# happy: ADJ
# inspiration: NOUN
# it: PRON
# was: AUX
# to: PART
# christen: VERB
# his: PRON
# ship: NOUN
# with: ADP
#
#
# Chunk 20 analysis:
# such: DET
# a: DET
# name: NOUN
# !: PUNCT
# It: PRON
# brought: VERB
# as: ADV
# from: ADP
# on: ADP
# high: ADJ
# a: DET
# new: ADJ
# spiritual: ADJ
# message: NOUN
# of: ADP
# peace: NOUN
# and: CCONJ
# good: NOUN
# -: PUNCT
# will: NOUN
# ,: PUNCT
# and: CCONJ
# it: PRON
# was: AUX
# more: ADJ
# than: ADP
# a: DET
# coincidence: NOUN
# that: PRON
# Lindbergh: PROPN
# should: AUX
# drop: VERB
# from: ADP
# his: PRON
# ship: NOUN
# his: PRON
# farewell: ADJ
# message: NOUN
# to: ADP
# Paris: PROPN
# on: ADP
# that: DET
# spot: NOUN
# ,: PUNCT
# in: ADP
# the: DET
# Place: PROPN
# de: X
# la: PROPN
# Concorde: PROPN
# ,: PUNCT
# where: SCONJ
# once: SCONJ
# the: DET
# Spirit: PROPN
# of: ADP
#
#
# Chunk 21 analysis:
# Saint: PROPN
# Louis: PROPN
# was: AUX
# invoked: VERB
# in: ADP
# tragic: ADJ
# circumstances: NOUN
# .: PUNCT
# The: DET
# priest: NOUN
# who: PRON
# stood: VERB
# there: ADV
# beside: ADP
# King: PROPN
# Louis: PROPN
# the: DET
# Sixteenth: PROPN
# as: SCONJ
# the: DET
# guillotine: NOUN
# fell: VERB
# ,: PUNCT
# cried: VERB
# defiantly: ADV
# to: ADP
# the: DET
# assembled: ADJ
# mob: NOUN
# :: PUNCT
# “: PUNCT
# The: DET
# Spirit: PROPN
# of: ADP
# Saint: PROPN
# Louis: PROPN
# ascends: VERB
# to: ADP
# the: DET
# skies: NOUN
# .: PUNCT
# ”: PUNCT
# With: ADP
# Lindbergh: PROPN
# ,: PUNCT
# _: NOUN
# out: ADP
# _: PROPN
# of: ADP
# the: DET
# skies: NOUN
# ,: PUNCT
# the: DET
# noble: ADJ
# Spirit: PROPN
# of: ADP
# Saint: PROPN
# Louis: PROPN
# came: VERB
# back: ADV
#
#
# Chunk 22 analysis:
# to: ADP
# France: PROPN
# .: PUNCT
# France: PROPN
# took: VERB
# Charles: PROPN
# Lindbergh: PROPN
# to: ADP
# her: PRON
# heart: NOUN
# because: SCONJ
# of: ADP
# what: PRON
# he: PRON
# was: AUX
# and: CCONJ
# because: SCONJ
# of: ADP
# what: PRON
# she: PRON
# knew: VERB
# he: PRON
# represented: VERB
# .: PUNCT
# His: PRON
# little: ADJ
# ship: NOUN
# came: VERB
# to: ADP
# the: DET
# meeting: NOUN
# place: NOUN
# of: ADP
# the: DET
# greatest: ADJ
# conference: NOUN
# that: PRON
# has: AUX
# ever: ADV
# gathered: VERB
# between: ADP
# two: NUM
# nations: NOUN
# ,: PUNCT
# for: ADP
# under: ADP
# the: DET
# shadow: NOUN
# of: ADP
# its: PRON
# wings: NOUN
# a: DET
# hundred: NUM
#
#
# Chunk 23 analysis:
# and: CCONJ
# fifty: NUM
# million: NUM
# Frenchmen: PROPN
# and: CCONJ
# Americans: PROPN
# have: AUX
# come: VERB
# together: ADV
# in: ADP
# generous: ADJ
# accord: NOUN
# .: PUNCT
# No: DET
# diplomatic: ADJ
# bag: NOUN
# ever: ADV
# carried: VERB
# so: ADV
# stupendous: ADJ
# a: DET
# document: NOUN
# as: ADP
# this: DET
# all: DET
# unaccredited: ADJ
# messenger: NOUN
# bore: NOUN
# ,: PUNCT
# and: CCONJ
# no: DET
# visiting: VERB
# squadron: NOUN
# ever: ADV
# delivered: VERB
# such: DET
# a: DET
# letter: NOUN
# of: ADP
# thanks: NOUN
# as: SCONJ
# he: PRON
# took: VERB
# up: ADP
# the: DET
# Potomac: PROPN
# in: ADP
# returning: VERB
# .: PUNCT
# Has: VERB
# any: DET
# such: ADJ
# Ambassador: NOUN
#
#
# Chunk 24 analysis:
# ever: ADV
# been: AUX
# known: VERB
# ?: PUNCT
# Lindbergh: PROPN
# was: AUX
# not: PART
# commissioned: VERB
# by: ADP
# our: PRON
# government: NOUN
# any: PRON
# more: ADV
# than: SCONJ
# Lafayette: PROPN
# was: AUX
# by: ADP
# his: PRON
# ;: PUNCT
# in: ADP
# each: DET
# case: NOUN
# it: PRON
# has: AUX
# been: AUX
# merely: ADV
# left: VERB
# for: SCONJ
# statesmen: NOUN
# to: PART
# register: VERB
# and: CCONJ
# approve: VERB
# the: DET
# vast: ADJ
# consequences: NOUN
# of: ADP
# their: PRON
# acts: NOUN
# .: PUNCT
# Both: PRON
# arrived: VERB
# at: ADP
# the: DET
# critical: ADJ
# moment: NOUN
# and: CCONJ
# both: PRON
# set: VERB
# in: ADP
# motion: NOUN
# those: PRON
# imponderable: ADJ
#
#
# Chunk 25 analysis:
# forces: NOUN
# which: PRON
# escape: VERB
# the: DET
# standards: NOUN
# of: ADP
# the: DET
# politician: NOUN
# ’s: PART
# mind: NOUN
# .: PUNCT
# Who: PRON
# shall: AUX
# say: VERB
# but: CCONJ
# that: SCONJ
# they: PRON
# were: AUX
# God: PROPN
# -: PUNCT
# sent: VERB
# messengers: NOUN
# of: ADP
# help: NOUN
# ,: PUNCT
# smiling: VERB
# defiance: NOUN
# of: ADP
# their: PRON
# faith: NOUN
# at: ADP
# an: DET
# all: ADV
# too: ADV
# skeptical: ADJ
# world: NOUN
# ?: PUNCT
# What: PRON
# one: NUM
# accomplished: VERB
# has: AUX
# already: ADV
# changed: VERB
# history: NOUN
# through: ADP
# a: DET
# century: NOUN
# ;: PUNCT
# what: PRON
# the: DET
# other: ADJ
# has: AUX
# just: ADV
# done: VERB
# the: DET
# people: NOUN
# of: ADP
#
#
# Chunk 26 analysis:
# America: PROPN
# and: CCONJ
# France: PROPN
# will: AUX
# take: VERB
# good: ADJ
# care: NOUN
# shall: AUX
# not: PART
# be: AUX
# wasted: VERB
# .: PUNCT
# The: DET
# way: NOUN
# Lindbergh: PROPN
# bore: VERB
# himself: PRON
# after: ADP
# getting: VERB
# here: ADV
# was: AUX
# but: CCONJ
# the: DET
# continuation: NOUN
# of: ADP
# his: PRON
# flight: NOUN
# .: PUNCT
# He: PRON
# started: VERB
# with: ADP
# no: DET
# purpose: NOUN
# but: CCONJ
# to: PART
# arrive: VERB
# .: PUNCT
# He: PRON
# remained: VERB
# with: ADP
# no: DET
# desire: NOUN
# but: CCONJ
# to: PART
# serve: VERB
# .: PUNCT
# He: PRON
# sought: VERB
# nothing: PRON
# ;: PUNCT
# he: PRON
# was: AUX
# offered: VERB
# all: PRON
# .: PUNCT
# No: INTJ
#
#
# Chunk 27 analysis:
# flaw: PROPN
# marked: VERB
# any: DET
# act: NOUN
# or: CCONJ
# word: NOUN
# ,: PUNCT
# and: CCONJ
# he: PRON
# stood: VERB
# forth: ADV
# amidst: ADP
# clamor: NOUN
# and: CCONJ
# crowds: NOUN
# the: DET
# very: ADV
# embodiment: ADJ
# of: ADP
# fearless: PROPN
# ,: PUNCT
# kindly: ADV
# ,: PUNCT
# cultivated: VERB
# ,: PUNCT
# American: ADJ
# youth: NOUN
# --: PUNCT
# unspoiled: VERB
# ,: PUNCT
# unspoilable: ADJ
# .: PUNCT
# A: DET
# nation: NOUN
# which: PRON
# breeds: VERB
# such: ADJ
# boys: NOUN
# need: AUX
# never: ADV
# fear: VERB
# for: ADP
# its: PRON
# future: NOUN
# .: PUNCT
# When: SCONJ
# a: DET
# contract: NOUN
# for: ADP
# one: NUM
# million: NUM
# dollars: NOUN
# was: AUX
# sent: VERB
# him: PRON
# through: ADP
# his: PRON
# associates: NOUN
# he: PRON
#
#
# Chunk 28 analysis:
# cabled: VERB
# back: ADV
# to: ADP
# them: PRON
# ,: PUNCT
# “: PUNCT
# You: PRON
# must: AUX
# remember: VERB
# this: DET
# expedition: NOUN
# was: AUX
# not: PART
# organized: VERB
# to: PART
# make: VERB
# money: NOUN
# but: CCONJ
# to: PART
# advance: VERB
# aviation: NOUN
# .: PUNCT
# ”: PUNCT
# There: PRON
# is: VERB
# the: DET
# measure: NOUN
# of: ADP
# his: PRON
# spirit: NOUN
# ;: PUNCT
# the: DET
# key: NOUN
# to: ADP
# his: PRON
# intentions: NOUN
# .: PUNCT
# Flying: VERB
# was: AUX
# his: PRON
# trade: NOUN
# ,: PUNCT
# his: PRON
# means: NOUN
# of: ADP
# livelihood: NOUN
# .: PUNCT
# But: CCONJ
# the: DET
# love: NOUN
# of: ADP
# it: PRON
# burned: VERB
# in: ADP
# him: PRON
# with: ADP
# fine: ADJ
# passion: NOUN
# ,: PUNCT
#
#
# Chunk 29 analysis:
# and: CCONJ
# now: ADV
# that: SCONJ
# his: PRON
# fame: NOUN
# will: AUX
# give: VERB
# him: PRON
# a: DET
# wider: ADJ
# scope: NOUN
# of: ADP
# usefulness: NOUN
# ,: PUNCT
# he: PRON
# has: AUX
# announced: VERB
# that: SCONJ
# he: PRON
# will: AUX
# devote: VERB
# himself: PRON
# wholeheartedly: ADV
# to: ADP
# the: DET
# advancement: NOUN
# of: ADP
# aeronautics: NOUN
# .: PUNCT
# His: PRON
# first: ADJ
# step: NOUN
# in: ADP
# that: DET
# direction: NOUN
# is: AUX
# the: DET
# publishing: NOUN
# of: ADP
# this: DET
# book: NOUN
# ,: PUNCT
# and: CCONJ
# no: DET
# one: NOUN
# can: AUX
# doubt: VERB
# that: SCONJ
# its: PRON
# influence: NOUN
# will: AUX
# be: AUX
# of: ADP
#
#
# Chunk 30 analysis:
# enormous: ADJ
# value: NOUN
# in: ADP
# pushing: VERB
# on: ADP
# man: NOUN
# ’s: PART
# conquest: NOUN
# of: ADP
# the: DET
# air: NOUN
# .: PUNCT
# It: PRON
# will: AUX
# be: AUX
# idle: ADJ
# for: ADP
# me: PRON
# or: CCONJ
# anyone: PRON
# else: ADV
# to: PART
# estimate: VERB
# now: ADV
# what: PRON
# these: DET
# results: NOUN
# will: AUX
# be: AUX
# .: PUNCT
# But: CCONJ
# America: PROPN
# vibrates: VERB
# with: ADP
# glowing: VERB
# pride: NOUN
# at: ADP
# the: DET
# thought: NOUN
# that: SCONJ
# out: ADP
# from: ADP
# our: PRON
# country: NOUN
# has: AUX
# come: VERB
# this: DET
# fresh: ADJ
# spirit: NOUN
# of: ADP
# the: DET
# air: NOUN
# and: CCONJ
#
#
# Chunk 31 analysis:
# that: SCONJ
# the: DET
# whole: ADJ
# world: NOUN
# hails: VERB
# Lindbergh: PROPN
# not: PART
# only: ADV
# as: ADP
# a: DET
# brave: ADJ
# aviator: NOUN
# but: CCONJ
# as: ADP
# an: DET
# example: NOUN
# of: ADP
# American: ADJ
# idealism: NOUN
# ,: PUNCT
# character: NOUN
# and: CCONJ
# conduct: NOUN
# .: PUNCT
# MYRON: PROPN
# T.: PROPN
# HERRICK: NOUN
# .: PUNCT
# _: PUNCT
# United: PROPN
# States: PROPN
# Embassy: PROPN
# Paris: PROPN
# June: PROPN
# Sixteenth: PROPN
# ,: PUNCT
# 1927: NUM
# _: NOUN
# CONTENTS: NOUN
# PAGE: NOUN
# I.--BOYHOOD: X
# AND: CCONJ
# EARLY: ADJ
# FLIGHTS: PROPN
# 19: NUM
# II.--MY: NOUN
# FIRST: PROPN
# PLANE: PROPN
# 39: NUM
# III.--BARNSTORMING: NOUN
# EXPERIENCE: PROPN
# 63: NUM
# IV.--HEADING: NOUN
# SOUTH: ADV
# 84: NUM
# V.--TRAINING: X
#
#
# Chunk 32 analysis:
# AT: ADP
# BROOKS: PROPN
# FIELD: NOUN
# 104: NUM
# VI.--RECEIVING: PROPN
# A: PROPN
# PILOT: PROPN
# ’S: PART
# WINGS: NOUN
# 126: NUM
# VII.--I: PROPN
# JOIN: PROPN
# THE: DET
# AIR: PROPN
# MAIL: PROPN
# 153: NUM
# VIII.--TWO: NOUN
# EMERGENCY: PROPN
# JUMPS: PROPN
# 175: NUM
# IX.--SAN: PROPN
# DIEGO: PROPN
# --: PUNCT
# ST: PROPN
# .: PUNCT
# LOUIS: PROPN
# --: PUNCT
# NEW: PROPN
# YORK: PROPN
# 198: NUM
# X.--NEW: PROPN
# YORK: PROPN
# TO: ADP
# PARIS: PROPN
# 213: NUM
# PUBLISHER: NOUN
# ’S: PART
# NOTE: NOUN
# 231: NUM
# AUTHOR: PROPN
# ’S: PROPN
# NOTE: NOUN
# 232: NUM
# A: DET
# LITTLE: PROPN
# OF: ADP
# WHAT: PRON
# THE: DET
# WORLD: PROPN
# THOUGHT: PROPN
# OF: ADP
# LINDBERGH: PROPN
# BY: INTJ
# FITZHUGH: VERB
# GREEN: PROPN
# I.--PARIS: PUNCT
# 233: NUM
# II.--BRUSSELS: ADV
#
#
# Chunk 33 analysis:
# 248: NUM
# III.--LONDON: PROPN
# 254: NUM
# IV.--WASHINGTON: PROPN
# 265: NUM
# V.--NEW: NOUN
# YORK: PROPN
# 297: NUM
# VI.--ST: PROPN
# .: PUNCT
# LOUIS: PROPN
# 315: NUM
# ILLUSTRATIONS: NOUN
# FACING: VERB
# PAGE: NOUN
# “: PUNCT
# WE: PROPN
# ”: PUNCT
# _: VERB
# Frontispiece: X
# _: NOUN
# FATHER: PROPN
# AND: CCONJ
# SON: PROPN
# 20: NUM
# INSTRUCTOR: NOUN
# AND: CCONJ
# CLASSMATES: NOUN
# IN: ADP
# A: DET
# MID: PROPN
# -: PROPN
# WESTERN: PROPN
# MILITARY: PROPN
# SCHOOL: PROPN
# 21: NUM
# SHIPPING: NOUN
# “: PUNCT
# THE: DET
# SPIRIT: PROPN
# OF: ADP
# ST: PROPN
# .: PUNCT
# LOUIS: PROPN
# ”: PUNCT
# 32: NUM
# THE: DET
# MEN: PROPN
# WHO: PRON
# MADE: VERB
# THE: DET
# PLANE: PROPN
# 33: NUM
# FINANCIAL: PROPN
# BACKERS: NOUN
# OF: ADP
# THE: DET
# NON: PROPN
# -: NOUN
# STOP: VERB
# NEW: PROPN
# YORK: PROPN
#
#
# Chunk 34 analysis:
# TO: ADP
# PARIS: PROPN
# FLIGHT: PROPN
# 50: NUM
# FUSELAGE: NOUN
# FRAME: NOUN
# OF: ADP
# THE: DET
# PLANE: PROPN
# 51: NUM
# WORKING: PROPN
# ON: ADP
# NAVIGATION: PROPN
# CHARTS: PROPN
# FOR: ADP
# FLIGHT: PROPN
# 66: NUM
# INSTRUMENT: PROPN
# BOARD: PROPN
# OF: ADP
# THE: DET
# PLANE: PROPN
# 67: NUM
# “: PUNCT
# WE: PROPN
# ”: PUNCT
# MAKE: VERB
# A: DET
# TEST: NOUN
# FLIGHT: PROPN
# 82: NUM
# PATSY: PROPN
# ,: PUNCT
# THE: DET
# MASCOT: PROPN
# 83: NUM
# POLICE: NOUN
# GUARDING: VERB
# “: PUNCT
# THE: DET
# SPIRIT: PROPN
# OF: ADP
# ST: PROPN
# .: PUNCT
# LOUIS: PROPN
# ”: PUNCT
# 98: NUM
# CAPTAIN: PROPN
# RENÉ: PROPN
# FONCK: PROPN
# WISHES: PROPN
# ME: PRON
# THE: DET
# BEST: NOUN
# OF: ADP
# LUCK: PROPN
#
#
# Chunk 35 analysis:
# 99: NUM
# GETTING: VERB
# READY: PROPN
# FOR: ADP
# THE: DET
# TAKE: PROPN
# -: PUNCT
# OFF: PROPN
# 114: NUM
# JUST: ADV
# BEFORE: ADP
# STARTING: VERB
# ON: ADP
# THE: DET
# BIG: PROPN
# ADVENTURE: NOUN
# 115: NUM
# “: PUNCT
# I: PRON
# DIDN’T: NOUN
# USE: VERB
# MY: PROPN
# PERISCOPE: NOUN
# ALL: DET
# THE: DET
# TIME: PROPN
# ”: PUNCT
# 118: NUM
# A: DET
# SALUTATION: NOUN
# FROM: ADP
# M.: PROPN
# BLERIOT: PROPN
# 119: NUM
# PAUL: PROPN
# PAINLEVÉ: PROPN
# EXTENDS: VERB
# HIS: PRON
# WELCOME: NOUN
# 126: NUM
# WITH: ADP
# M.: PROPN
# DOUMERQUE: NOUN
# AND: CCONJ
# AMBASSADOR: PROPN
# HERRICK: VERB
# 127: NUM
# CROWDS: NOUN
# AT: ADP
# THE: DET
# CITY: PROPN
# HALL: PROPN
# 130: NUM
# GUESTS: NOUN
#
#
# Chunk 36 analysis:
# AT: ADP
# THE: DET
# LUNCHEON: PROPN
# OF: ADP
# M.: PROPN
# BLERIOT: PROPN
# 131: NUM
# ON: ADP
# THE: DET
# STEPS: PROPN
# OF: ADP
# THE: DET
# EMBASSY: PROPN
# 146: NUM
# THE: DET
# WELCOME: NOUN
# AT: PROPN
# CROYDEN: PROPN
# FIELD: NOUN
# 147: NUM
# WITH: ADP
# CROWN: PROPN
# PRINCE: PROPN
# LEOPOLD: PROPN
# 162: NUM
# WITH: ADP
# H.: PROPN
# R.: PROPN
# H.: PROPN
# THE: DET
# PRINCE: PROPN
# OF: ADP
# WALES: PROPN
# AND: CCONJ
# LORD: PROPN
# LONSDALE: PROPN
# 163: NUM
# CROWDS: NOUN
# PRESSING: VERB
# AROUND: ADP
# “: PUNCT
# THE: DET
# SPIRIT: PROPN
# OF: ADP
# ST: PROPN
# .: PUNCT
# LOUIS: PROPN
# ”: PUNCT
# AS: ADP
# THE: DET
# PLANE: PROPN
# LANDED: PROPN
# 178: NUM
#
#
# Chunk 37 analysis:
# “: PUNCT
# AT: PROPN
# CROYDEN: NOUN
# FIELD: NOUN
# I: PRON
# ESCAPED: VERB
# TO: ADP
# THE: DET
# TOP: PROPN
# OF: ADP
# THE: DET
# OBSERVATION: PROPN
# TOWER: NOUN
# OVERLOOKING: VERB
# THE: DET
# CROWD: NOUN
# ”: PUNCT
# 179: NUM
# THE: DET
# U.: PROPN
# S.: PROPN
# S.: PROPN
# “: PUNCT
# MEMPHIS: PROPN
# ,: PUNCT
# ”: PUNCT
# FLAGSHIP: PROPN
# ,: PUNCT
# ON: PROPN
# WHICH: PRON
# THE: DET
# AUTHOR: NOUN
# RETURNED: VERB
# TO: ADP
# AMERICA: PROPN
# 194: NUM
# COMING: VERB
# DOWN: ADP
# THE: DET
# GANGPLANK: PROPN
# OF: ADP
# THE: DET
# U.: PROPN
# S.: PROPN
# S.: PROPN
# “: PUNCT
# MEMPHIS: PROPN
# ”: PUNCT
# 195: NUM
# CHARLES: PROPN
# EVANS: PROPN
# HUGHES: PROPN
# CONFERS: VERB
# THE: DET
# CROSS: NOUN
# OF: ADP
# HONOR: PROPN
# 210: NUM
#
#
# Chunk 38 analysis:
# AT: ADP
# THE: DET
# TOMB: PROPN
# OF: ADP
# “: PUNCT
# THE: DET
# UNKNOWN: ADJ
# SOLDIER: NOUN
# ”: PUNCT
# 211: NUM
# SPEECHES: PROPN
# AT: PROPN
# WASHINGTON: PROPN
# MONUMENT: PROPN
# 226: NUM
# FROM: ADP
# THE: DET
# TOP: PROPN
# OF: ADP
# WASHINGTON: PROPN
# MONUMENT: PROPN
# 227: NUM
# AT: PROPN
# ARLINGTON: PROPN
# CEMETERY: PROPN
# 234: NUM
# THE: DET
# $: SYM
# 25,000: NUM
# CHECK: NOUN
# PRESENTED: VERB
# BY: ADP
# RAYMOND: PROPN
# ORTEIG: PROPN
# 235: NUM
# RECEIVING: VERB
# THE: DET
# ORTEIG: PROPN
# PRIZE: PROPN
# MEDAL: PROPN
# 235: NUM
# WELCOME: NOUN
# IN: ADP
# NEW: PROPN
# YORK: PROPN
# HARBOR: PROPN
# 242: NUM
# RIDING: NOUN
# UP: ADP
# BROADWAY: PROPN
# 243: NUM
# NEW: PROPN
# YORK: PROPN
#
#
# Chunk 39 analysis:
# CITY: PROPN
# ’S: PROPN
# WELCOME: PROPN
# 258: NUM
# A: DET
# JUNE: PROPN
# SNOWSTORM: PROPN
# 259: NUM
# THE: DET
# PARADE: NOUN
# PASSING: VERB
# THROUGH: ADP
# CENTRAL: ADJ
# PARK: PROPN
# 274: NUM
# THE: DET
# PARADE: NOUN
# IN: ADP
# CENTRAL: ADJ
# PARK: PROPN
# 275: NUM
# SPEAKING: VERB
# AT: ADP
# THE: DET
# CEREMONIES: NOUN
# IN: ADP
# CENTRAL: ADJ
# PARK: PROPN
# 290: NUM
# SPEAKING: VERB
# AT: ADP
# THE: DET
# CEREMONIES: NOUN
# IN: ADP
# PROSPECT: PROPN
# PARK: PROPN
# 291: NUM
# “: PUNCT
# THE: DET
# SPIRIT: PROPN
# OF: ADP
# ST: PROPN
# .: PUNCT
# LOUIS: PROPN
# ”: PUNCT
# AFTER: ADP
# HER: PRON
# RETURN: PROPN
# 306: NUM
# AFTER: ADP
# THE: DET
# FLIGHT: PROPN
# TO: ADP
# WASHINGTON: PROPN
#
#
# Chunk 40 analysis:
# 307: NUM
# ST: PROPN
# .: PUNCT
# LOUIS: PROPN
# ’: PUNCT
# WELCOME: PROPN
# 314: NUM
# MY: PROPN
# MOTHER: PROPN
# 315: NUM
# “: PUNCT
# WE: PROPN
# ”: PUNCT
# I: PROPN
# BOYHOOD: PROPN
# AND: CCONJ
# EARLY: ADJ
# FLIGHTS: PROPN
# I: PRON
# was: AUX
# born: VERB
# in: ADP
# Detroit: PROPN
# ,: PUNCT
# Michigan: PROPN
# ,: PUNCT
# on: ADP
# February: PROPN
# 4: NUM
# ,: PUNCT
# 1902: NUM
# .: PUNCT
# My: PRON
# father: NOUN
# was: AUX
# practicing: VERB
# law: NOUN
# in: ADP
# Little: PROPN
# Falls: PROPN
# ,: PUNCT
# Minnesota: PROPN
# ,: PUNCT
# at: ADP
# the: DET
# time: NOUN
# .: PUNCT
# When: SCONJ
# I: PRON
# was: AUX
# less: ADJ
# than: ADP
# two: NUM
# months: NOUN
# old: ADJ
# my: PRON
# parents: NOUN
# took: VERB
# me: PRON
# to: ADP
# their: PRON
#
#
# Chunk 41 analysis:
# farm: NOUN
# ,: PUNCT
# on: ADP
# the: DET
# western: ADJ
# banks: NOUN
# of: ADP
# the: DET
# Mississippi: PROPN
# River: PROPN
# two: NUM
# miles: NOUN
# south: ADV
# of: ADP
# Little: PROPN
# Falls: PROPN
# .: PUNCT
# My: PRON
# father: NOUN
# ,: PUNCT
# Charles: PROPN
# A.: PROPN
# Lindbergh: PROPN
# ,: PUNCT
# was: AUX
# born: VERB
# in: ADP
# Stockholm: PROPN
# ,: PUNCT
# Sweden: PROPN
# ,: PUNCT
# January: PROPN
# 20: NUM
# ,: PUNCT
# 1860: NUM
# ,: PUNCT
# the: DET
# son: NOUN
# of: ADP
# Ola: PROPN
# and: CCONJ
# Louisa: PROPN
# Manson: PROPN
# .: PUNCT
# His: PRON
# father: NOUN
# (: PUNCT
# who: PRON
# changed: VERB
# his: PRON
# name: NOUN
# to: ADP
# Lindbergh: PROPN
# after: ADP
# reaching: VERB
# America: PROPN
# ): PUNCT
# was: AUX
# a: DET
# member: NOUN
# of: ADP
#
#
# Chunk 42 analysis:
# the: DET
# Swedish: PROPN
# Parliament: PROPN
# and: CCONJ
# had: AUX
# at: ADP
# one: NUM
# time: NOUN
# been: AUX
# Secretary: PROPN
# to: ADP
# the: DET
# King: PROPN
# .: PUNCT
# About: ADV
# 1860: NUM
# my: PRON
# grandfather: NOUN
# with: ADP
# his: PRON
# family: NOUN
# embarked: VERB
# on: ADP
# a: DET
# ship: NOUN
# bound: VERB
# for: ADP
# America: PROPN
# ,: PUNCT
# and: CCONJ
# settled: VERB
# near: ADP
# Sauk: PROPN
# Center: PROPN
# ,: PUNCT
# Minnesota: PROPN
# ,: PUNCT
# where: SCONJ
# he: PRON
# took: VERB
# up: ADP
# a: DET
# homestead: NOUN
# and: CCONJ
# built: VERB
# his: PRON
# first: ADJ
# home: NOUN
# in: ADP
# America: PROPN
# --: PUNCT
# a: DET
# log: NOUN
# cabin: NOUN
# .: PUNCT
# It: PRON
# was: AUX
#
#
# Chunk 43 analysis:
# here: ADV
# that: SCONJ
# my: PRON
# father: NOUN
# spent: VERB
# his: PRON
# early: ADJ
# life: NOUN
# .: PUNCT
# The: DET
# Rev.: PROPN
# C.: PROPN
# S.: PROPN
# Harrison: PROPN
# ,: PUNCT
# writing: VERB
# for: ADP
# the: DET
# Minnesota: PROPN
# Historical: PROPN
# Society: PROPN
# ,: PUNCT
# gives: VERB
# an: DET
# account: NOUN
# of: ADP
# the: DET
# activities: NOUN
# of: ADP
# my: PRON
# grandfather: NOUN
# during: ADP
# the: DET
# early: ADJ
# days: NOUN
# in: ADP
# Minnesota: PROPN
# .: PUNCT
# There: PRON
# were: VERB
# very: ADV
# few: ADJ
# schools: NOUN
# in: ADP
# Minnesota: PROPN
# at: ADP
# that: DET
# time: NOUN
# ,: PUNCT
# and: CCONJ
# my: PRON
# father: NOUN
# ’s: PART
# boyhood: NOUN
# days: NOUN
# were: AUX
#
#
# Chunk 44 analysis:
# spent: VERB
# mostly: ADV
# in: ADP
# hunting: NOUN
# and: CCONJ
# fishing: NOUN
# .: PUNCT
# His: PRON
# education: NOUN
# consisted: VERB
# largely: ADV
# of: ADP
# home: NOUN
# study: NOUN
# with: ADP
# an: DET
# occasional: ADJ
# short: ADJ
# term: NOUN
# at: ADP
# country: NOUN
# schools: NOUN
# .: PUNCT
# He: PRON
# was: AUX
# educated: VERB
# at: ADP
# Grove: PROPN
# Lake: PROPN
# Academy: PROPN
# ,: PUNCT
# Minnesota: PROPN
# ,: PUNCT
# and: CCONJ
# graduated: VERB
# from: ADP
# the: DET
# law: NOUN
# school: NOUN
# at: ADP
# the: DET
# University: PROPN
# of: ADP
# Michigan: PROPN
# ,: PUNCT
# Ann: PROPN
# Arbor: PROPN
# ,: PUNCT
# with: ADP
# an: DET
# LL.B.: NOUN
# degree: NOUN
# .: PUNCT
# He: PRON
# began: VERB
# his: PRON
# law: NOUN
#
#
# Chunk 45 analysis:
# practice: NOUN
# in: ADP
# Little: PROPN
# Falls: PROPN
# where: SCONJ
# he: PRON
# served: VERB
# as: ADP
# County: PROPN
# Attorney: PROPN
# .: PUNCT
# He: PRON
# later: ADV
# became: VERB
# interested: ADJ
# in: ADP
# politics: NOUN
# ,: PUNCT
# and: CCONJ
# was: AUX
# elected: VERB
# to: ADP
# the: DET
# 60th: ADJ
# Congress: PROPN
# in: ADP
# 1906: NUM
# to: PART
# represent: VERB
# the: DET
# Sixth: PROPN
# District: PROPN
# of: ADP
# Minnesota: PROPN
# at: ADP
# Washington: PROPN
# ,: PUNCT
# a: DET
# capacity: NOUN
# in: ADP
# which: PRON
# he: PRON
# served: VERB
# for: ADP
# ten: NUM
# years: NOUN
# .: PUNCT
# [: X
# Illustration: NOUN
# :: PUNCT
# ©: NOUN
# _: NOUN
# Wide: ADJ
# World: PROPN
# Photos: PROPN
# _: PROPN
# FATHER: PROPN
# AND: CCONJ
#
#
# Chunk 46 analysis:
# SON: NOUN
# ]: PUNCT
# [: X
# Illustration: NOUN
# :: PUNCT
# ©: NOUN
# _: NOUN
# Wide: ADJ
# World: PROPN
# Photos: PROPN
# _: PROPN
# MADISON: PROPN
# ,: PUNCT
# WISC.--INSTRUCTOR: PROPN
# AND: CCONJ
# CLASSMATES: PROPN
# IN: ADP
# A: DET
# MID: PROPN
# -: PROPN
# WESTERN: PROPN
# MILITARY: PROPN
# SCHOOL: PROPN
# ]: PUNCT
# My: PRON
# mother: NOUN
# was: AUX
# born: VERB
# in: ADP
# Detroit: PROPN
# ,: PUNCT
# Michigan: PROPN
# ,: PUNCT
# daughter: NOUN
# of: ADP
# Charles: PROPN
# and: CCONJ
# Evangeline: PROPN
# Land: PROPN
# .: PUNCT
# She: PRON
# is: AUX
# of: ADP
# English: PROPN
# ,: PUNCT
# Irish: ADJ
# and: CCONJ
# French: ADJ
# extraction: NOUN
# .: PUNCT
# As: ADP
# a: DET
# graduate: NOUN
# of: ADP
# the: DET
# University: PROPN
# of: ADP
# Michigan: PROPN
# ,: PUNCT
# she: PRON
# holds: VERB
# a: DET
# B.S.: PROPN
# degree: NOUN
# from: ADP
#
#
# Chunk 47 analysis:
# that: DET
# institution: NOUN
# ,: PUNCT
# also: ADV
# an: DET
# A.M.: PROPN
# degree: NOUN
# from: ADP
# Columbia: PROPN
# University: PROPN
# ,: PUNCT
# New: PROPN
# York: PROPN
# City: PROPN
# .: PUNCT
# Her: PRON
# father: NOUN
# ,: PUNCT
# Dr.: PROPN
# Charles: PROPN
# H.: PROPN
# Land: PROPN
# ,: PUNCT
# a: DET
# Detroit: PROPN
# dentist: NOUN
# ,: PUNCT
# was: AUX
# born: VERB
# in: ADP
# Simcoe: PROPN
# ,: PUNCT
# Norfolk: PROPN
# County: PROPN
# ,: PUNCT
# Canada: PROPN
# ,: PUNCT
# and: CCONJ
# his: PRON
# father: NOUN
# ,: PUNCT
# Colonel: PROPN
# John: PROPN
# Scott: PROPN
# Land: PROPN
# ,: PUNCT
# came: VERB
# from: ADP
# England: PROPN
# ,: PUNCT
# and: CCONJ
# was: AUX
# one: NUM
# of: ADP
# the: DET
# founders: NOUN
# of: ADP
# the: DET
# present: ADJ
# city: NOUN
# of: ADP
# Hamilton: PROPN
# .: PUNCT
#
#
# Chunk 48 analysis:
# My: PRON
# grandfather: NOUN
# was: AUX
# constantly: ADV
# experimenting: VERB
# in: ADP
# his: PRON
# laboratory: NOUN
# .: PUNCT
# He: PRON
# held: VERB
# a: DET
# number: NOUN
# of: ADP
# patents: NOUN
# on: ADP
# incandescent: NOUN
# grates: NOUN
# and: CCONJ
# furnaces: NOUN
# ,: PUNCT
# in: ADP
# addition: NOUN
# to: ADP
# several: ADJ
# on: ADP
# gold: NOUN
# and: CCONJ
# enamel: NOUN
# inlays: NOUN
# and: CCONJ
# other: ADJ
# dental: ADJ
# processes: NOUN
# .: PUNCT
# He: PRON
# was: AUX
# one: NUM
# of: ADP
# the: DET
# first: ADJ
# to: PART
# foresee: VERB
# the: DET
# possibilities: NOUN
# of: ADP
# porcelain: NOUN
# in: ADP
# dentistry: NOUN
# ,: PUNCT
# and: CCONJ
# later: ADV
# became: AUX
# known: VERB
#
#
# Chunk 49 analysis:
# as: ADP
# “: PUNCT
# the: DET
# father: NOUN
# of: ADP
# porcelain: VERB
# dental: ADJ
# art: NOUN
# .: PUNCT
# ”: PUNCT
# During: ADP
# the: DET
# first: ADJ
# four: NUM
# years: NOUN
# of: ADP
# my: PRON
# life: NOUN
# ,: PUNCT
# I: PRON
# lived: VERB
# in: ADP
# our: PRON
# Minnesota: PROPN
# home: NOUN
# with: ADP
# the: DET
# exception: NOUN
# of: ADP
# a: DET
# few: ADJ
# trips: NOUN
# to: ADP
# Detroit: PROPN
# .: PUNCT
# Then: ADV
# my: PRON
# father: NOUN
# was: AUX
# elected: VERB
# to: ADP
# Congress: PROPN
# and: CCONJ
# thereafter: ADV
# I: PRON
# seldom: ADV
# spent: VERB
# more: ADJ
# than: ADP
# a: DET
# few: ADJ
# months: NOUN
# in: ADP
# the: DET
# same: ADJ
#
#
# Chunk 50 analysis:
# place: NOUN
# .: PUNCT
# Our: PRON
# winters: NOUN
# were: AUX
# passed: VERB
# in: ADP
# Washington: PROPN
# ,: PUNCT
# and: CCONJ
# our: PRON
# summers: NOUN
# in: ADP
# Minnesota: PROPN
# ,: PUNCT
# with: ADP
# intermediate: ADJ
# visits: NOUN
# to: ADP
# Detroit: PROPN
# .: PUNCT
# When: SCONJ
# I: PRON
# was: AUX
# eight: NUM
# years: NOUN
# of: ADP
# age: NOUN
# I: PRON
# entered: VERB
# the: DET
# Force: PROPN
# School: PROPN
# in: ADP
# Washington: PROPN
# .: PUNCT
# My: PRON
# schooling: NOUN
# was: AUX
# very: ADV
# irregular: ADJ
# due: ADP
# to: ADP
# our: PRON
# constant: ADJ
# moving: VERB
# from: ADP
# place: NOUN
# to: ADP
# place: NOUN
# .: PUNCT
# Up: ADP
# to: ADP
# the: DET
# time: NOUN
# I: PRON
#
#
# Chunk 51 analysis:
# entered: VERB
# the: DET
# University: PROPN
# of: ADP
# Wisconsin: PROPN
# I: PRON
# had: AUX
# never: ADV
# attended: VERB
# for: ADP
# one: NUM
# full: ADJ
# school: NOUN
# year: NOUN
# ,: PUNCT
# and: CCONJ
# I: PRON
# had: AUX
# received: VERB
# instruction: NOUN
# from: ADP
# over: ADP
# a: DET
# dozen: NOUN
# institutions: NOUN
# ,: PUNCT
# both: CCONJ
# public: ADJ
# and: CCONJ
# private: ADJ
# ,: PUNCT
# from: ADP
# Washington: PROPN
# to: ADP
# California: PROPN
# .: PUNCT
# Through: ADP
# these: DET
# years: NOUN
# I: PRON
# crossed: VERB
# and: CCONJ
# recrossed: VERB
# the: DET
# United: PROPN
# States: PROPN
# ,: PUNCT
# made: VERB
# one: NUM
# trip: NOUN
# to: ADP
# Panama: PROPN
# ,: PUNCT
# and: CCONJ
# had: VERB
# thoroughly: ADV

# %% [markdown]
# ### Insights
#
# #### Most Common Parts Of Speech:
# 1. Proper Nouns: Proper Nouns such as names of people, names of organizations, names of places are very common.
# 2. Nouns: Nouns like school, life, father, mother, education etc. are also abundant.
# 3. Verbs: Verbs like was, born, lived, attended etc. are common, describing events and actions.
#
# #### Uncommon Parts Of Speech:
# 1. Numbers: Entities such as numbers are very rare in the text.
# 2. Punctuations: Punctuations are very rare and carry comparitively a lesser meaning than the other parts of speech
#
# ### Conclusion:
# From the above insights we can conclude that the book "We" is an autobiographical account of his life, people around him and the places he's been to as the most used Parts of Speech indicate.

# %% [markdown]
# ## Exercise 2
#
# Apply spaCy to extract the most meaningful content from your documents, considering options like excluding stop words or focusing on nouns (i.e. preprocessing and filtering).
#
# Perform a sentiment analysis on the refined data. Create visualization of your result.
#
# Summarize your results by explaining how sentiment changes across sections.

# %%
from spacy.lang.en.stop_words import STOP_WORDS
import matplotlib.pyplot as plt

nlp = spacy.load("en_core_web_sm")

def preprocess_text(text):
    doc = nlp(text)
    meaningful_tokens = [token.text for token in doc if token.text.lower() not in STOP_WORDS and token.pos_ == "NOUN"]
    return " ".join(meaningful_tokens)
    
def perform_sentiment_analysis(text):
    doc = nlp(text)
    sentiment_score = doc.sentiment
    return sentiment_score

url = "https://www.gutenberg.org/cache/epub/5200/pg5200.txt"

response = requests.get(url)
text = response.text

preprocessed_text = preprocess_text(text)

sentiment_score = perform_sentiment_analysis(preprocessed_text)

print("Sentiment Score:", sentiment_score)

labels = ['Positive', 'Negative']
sizes = [sentiment_score, 1 - sentiment_score]
colors = ['green', 'red']

plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
plt.axis('equal')
plt.title('Sentiment Analysis Result')
plt.show()
# Out:
# Sentiment Score: 0.0

# %% [markdown]
# ### Inferences:
# 1. The sentiment analysis shows that there is a 100% negative context to the book
# 2. We might need to look into few things to understand what caused this
#    1. The context of the book
#    2. The words filtered out by our model
#    3. The accuracy of the sentiment analysis model used
#
# ### Conclusion:
# The book used for the sentiment analysis is "Metamorphosis" By Franz Kafka. The book in itself is a depressing account of an incident that occurs in the life of the protagonist which ultimately leads to his death. So, the conclusion that the text is very negative by our model could be accurate, but giving a 100% negative score might not be a better representation of the text.
